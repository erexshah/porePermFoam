# %%
smpls = ["beadpack", "bentheimer", "berea", "doddington", "estaillades", "gildehauser", "ketton", "portland"]
sizes = [2e-6, 3.0035e-6, 2.7745e-6, 2.6929e-6, 3.31136e-6, 4.4e-6, 3.00006e-6, 4.525e-6]
sample = smpls[1]  # choose sample
size = sizes[1]    # choose size

# %%
import simpleFoam_tools as sft
import pandas as pd
import numpy as np

# %%
remove = 1
if remove:
    sft.remove_run_files(f"{sample}")

# %%
domain_name = f"{sample}_z"  # "cylinder" or "vti_bent_x"

scale = size  # voxel size [m]
dp = 1.0           # pressure difference [Pa]
refinement = 1    # local refinement level
factor_mesh_x = 1.0    # global mesh scale factor
factor_mesh_y = 1.0    # global mesh scale factor
factor_mesh_z = 1.0    # global mesh scale factor

boundary_type = "symmetryPlane"  # "symmetryPlane" or "Wall"

dt = 1e-6
end_time = 50e-6
write_interval = 10

# %%
# Get voxel shape and a pore voxel location from VTI
vti_path = f"{sample}/constant/geometry/{domain_name}.vti"
shape = sft.vti_shape(vti_path)
location_in_mesh = sft.find_pore_location(vti_path)

# Convert VTI to STL surface mesh
stl = f"{domain_name}.stl"
stl_path = f"{sample}/constant/triSurface/{stl}"
sft.vti_to_stl(vti_path, stl_path)

# Adjust mesh resolution
mesh_resolution = (int(shape[0]*factor_mesh_x), int(shape[1]*factor_mesh_y), int(shape[2]*factor_mesh_z))

# File paths
blockMeshDict_path    = f"{sample}/system/blockMeshDict"
controlDict_path      = f"{sample}/system/controlDict"
p_field_path          = f"{sample}/0/p"
U_field_path          = f"{sample}/0/U"
snappyHexMeshDict_path = f"{sample}/system/snappyHexMeshDict"
# Generate OpenFOAM files
sft.generate_blockMeshDict(shape, mesh_resolution, blockMeshDict_path, boundary=boundary_type)
sft.generate_snappyHexMeshDict(location_in_mesh, stl, snappyHexMeshDict_path, refinement=refinement)
sft.generate_controlDict(controlDict_path, end_time=end_time, write_interval=write_interval, dt=dt)
sft.generate_pressure_field(p_field_path, dp=dp, boundary=boundary_type)
sft.generate_velocity_field(U_field_path, boundary=boundary_type)
# Out:
# Running command: pvpython /home/h09435ap/porePermFoam/simpleFoam_tools/paraview_stl.py /home/h09435ap/porePermFoam/bentheimer/constant/geometry/bentheimer_z.vti /home/h09435ap/porePermFoam/bentheimer/constant/triSurface/bentheimer_z.stl
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# ✅ Wrote ASCII STL: /home/h09435ap/porePermFoam/bentheimer/constant/triSurface/bentheimer_z.stl
# Generated blockMeshDict at: bentheimer/system/blockMeshDict
# Generated snappyHexMeshDict at: bentheimer/system/snappyHexMeshDict
# Generated controlDict at: bentheimer/system/controlDict
# Generated p at: bentheimer/0/p with boundary symmetryPlane
# Generated U at: bentheimer/0/U with boundary symmetryPlane

# %%
sft.run_simplefoam(f"{sample}", scale=scale)
# Out:
# >>> blockMesh
#
# /*---------------------------------------------------------------------------*\
# | =========                 |                                                 |
# | \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox           |
# |  \\    /   O peration     | Version:  2412                                  |
# |   \\  /    A nd           | Website:  www.openfoam.com                      |
# |    \\/     M anipulation  |                                                 |
# \*---------------------------------------------------------------------------*/
# Build  : _e5c6ccc3-20250814 OPENFOAM=2412 patch=250814 version=2412
# Arch   : "LSB;label=32;scalar=64"
# Exec   : blockMesh
# Date   : Feb 04 2026
# Time   : 14:13:13
# Host   : e-10aux32876g5
# PID    : 270045
# I/O    : uncollated
# Case   : /home/h09435ap/porePermFoam/bentheimer
# nProcs : 1
# trapFpe: Floating point exception trapping enabled (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 5, maxFileModificationPolls 20)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# --> FOAM Warning :
#     From static Foam::IOstreamOption::compressionType Foam::IOstreamOption::compressionEnum(const Foam::word&, Foam::IOstreamOption::compressionType)
#     in file db/options/IOstreamOption.C at line 189
#     Unknown compression specifier 'uncompressed' using compression off
# Creating block mesh from "system/blockMeshDict"
# Creating block edges
# No non-planar block faces defined
# Creating topology blocks
#
# Creating topology patches - from boundary section
#
# Creating block mesh topology
#
# Check topology
#
# 	Basic statistics
# 		Number of internal faces : 0
# 		Number of boundary faces : 6
# 		Number of defined boundary faces : 6
# 		Number of undefined boundary faces : 0
# 	Checking patch -> block consistency
#
# Creating block offsets
# Creating merge list (topological search)...
#
# Creating polyMesh from blockMesh
# Creating patches
# Creating cells
# Creating points with scale (1 1 1)
#     Block 0 cell size :
#         i : 0.996 .. 0.996
#         j : 0.996 .. 0.996
#         k : 0.996 .. 0.996
#
# No patch pairs to merge
#
# Writing polyMesh with 0 cellZones
# ----------------
# Mesh Information
# ----------------
#   boundingBox: (0 0 0) (249 249 249)
#   nPoints: 15813251
#   nCells: 15625000
#   nFaces: 47062500
#   nInternalFaces: 46687500
# ----------------
# Patches
# ----------------
#   patch 0 (start: 46687500 size: 62500) name: top
#   patch 1 (start: 46750000 size: 62500) name: inlet
#   patch 2 (start: 46812500 size: 62500) name: bottom
#   patch 3 (start: 46875000 size: 62500) name: outlet
#   patch 4 (start: 46937500 size: 62500) name: front
#   patch 5 (start: 47000000 size: 62500) name: back
#
# End
#
#
# >>> snappyHexMesh -overwrite
#
# /*---------------------------------------------------------------------------*\
# | =========                 |                                                 |
# | \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox           |
# |  \\    /   O peration     | Version:  2412                                  |
# |   \\  /    A nd           | Website:  www.openfoam.com                      |
# |    \\/     M anipulation  |                                                 |
# \*---------------------------------------------------------------------------*/
# Build  : _e5c6ccc3-20250814 OPENFOAM=2412 patch=250814 version=2412
# Arch   : "LSB;label=32;scalar=64"
# Exec   : snappyHexMesh -overwrite
# Date   : Feb 04 2026
# Time   : 14:15:00
# Host   : e-10aux32876g5
# PID    : 270280
# I/O    : uncollated
# Case   : /home/h09435ap/porePermFoam/bentheimer
# nProcs : 1
# trapFpe: Floating point exception trapping enabled (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 5, maxFileModificationPolls 20)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# --> FOAM Warning :
#     From static Foam::IOstreamOption::compressionType Foam::IOstreamOption::compressionEnum(const Foam::word&, Foam::IOstreamOption::compressionType)
#     in file db/options/IOstreamOption.C at line 189
#     Unknown compression specifier 'uncompressed' using compression off
# Create mesh for time = 0
#
# Read mesh in = 81.45 s
#
# Overall mesh bounding box  : (0 0 0) (249 249 249)
# Relative tolerance         : 1e-06
# Absolute matching distance : 0.000431281
#
# Reading refinement surfaces.
# Read refinement surfaces in = 3.27 s
#
# Reading refinement shells.
# Read refinement shells in = 0 s
#
# Setting refinement level of surface to be consistent with shells.
# For geometry bentheimer_z.stl detected 0 uncached triangles out of 2731572
# Checked shell refinement in = 8.93 s
#
# Reading features.
# Read features in = 0 s
#
#
# Determining initial surface intersections
# -----------------------------------------
#
# Edge intersection testing:
#     Number of edges             : 47062500
#     Number of edges to retest   : 0
#     Number of intersected edges : 0
# Edge intersection testing:
#     Number of edges             : 47062500
#     Number of edges to retest   : 47062500
#     Number of intersected edges : 1376828
# Calculated surface intersections in = 58.76 s
#
# Initial mesh : cells:15625000  faces:47062500  points:15813251
# Cells per refinement level:
#     0	15625000
# Setting refinement level of surface to be consistent with curvature.
# Checked curvature refinement in = 0.08 s
#
#
# Adding patches for surface regions
# ----------------------------------
#
# Patch Type                Region
# ----- ----                ------
# solids:
#
# 6     wall                solids
#
# Added patches in = 0.52 s
#
# Edge intersection testing:
#     Number of edges             : 47062500
#     Number of edges to retest   : 0
#     Number of intersected edges : 1376828
# Decomposition method none [1]
#
# Refinement phase
# ----------------
#
# Found point (125 125 121) in cell 7593875 on processor 0
#
# Surface refinement iteration 0
# ------------------------------
#
# No cells marked for refinement since reached limit 2000000.
# Determined cells to refine in = 12.75 s
# Selected for refinement : 0 cells (out of 15625000)
# Stopping refining since too few cells selected.
#
#
# Removing mesh beyond surface intersections
# ------------------------------------------
#
# Setting cellZones according to locationsInMesh:
# Location : (125 125 121)
#     cellZone : none
#
# For cellZone none found point (125 125 121) in global region 1 out of 150 regions.
# --> FOAM Warning :
#     From void Foam::meshRefinement::nearestFace(const labelUList&, const Foam::bitSet&, Foam::autoPtr<Foam::mapDistribute>&, Foam::labelList&, Foam::label) const
#     in file meshRefinement/meshRefinement.C at line 527
#     Did not visit some faces, e.g. face 8120 at (210.156 10.458 0.498)
# Keeping all cells containing inside points
# Selected for keeping : 4891763 cells.
# Edge intersection testing:
#     Number of edges             : 15528175
#     Number of edges to retest   : 1331262
#     Number of intersected edges : 1376828
#
# Shell refinement iteration 0
# ----------------------------
#
# No cells marked for refinement since reached limit 2000000.
# Determined cells to refine in = 40.94 s
# Selected for internal refinement : 0 cells (out of 4891763)
# Stopping refining since too few cells selected.
#
#
# Dangling coarse cells refinement iteration 0
# --------------------------------------------
#
# Determined cells to refine in = 0.22 s
# Selected for refinement : 0 cells (out of 4891763)
# Stopping refining since too few cells selected.
#
#
# Dangling coarse cells refinement iteration 0
# --------------------------------------------
#
# Determined cells to refine in = 0.23 s
# Selected for refinement : 0 cells (out of 4891763)
# Stopping refining since too few cells selected.
#
#
# Refinement transition refinement iteration 0
# --------------------------------------------
#
# Determined cells to refine in = 0.25 s
# Selected for refinement : 0 cells (out of 4891763)
# Stopping refining since too few cells selected.
#
#
# Splitting mesh at surface intersections
# ---------------------------------------
#
# Introducing baffles for 1376828 faces that are intersected by the surface.
#
# Setting cellZones according to locationsInMesh:
# Location : (125 125 121)
#     cellZone : none
#
# For cellZone none found point (125 125 121) in global region 1 out of 857 regions.
# Edge intersection testing:
#     Number of edges             : 16616460
#     Number of edges to retest   : 6968749
#     Number of intersected edges : 2465113
# Created baffles in = 22.3 s
#
#
# After introducing baffles : cells:4891763  faces:16616460  points:5746120
# Cells per refinement level:
#     0	4891763
#
# Introducing baffles to block off problem cells
# ----------------------------------------------
#
# markFacesOnProblemCells : marked 2705386 additional internal faces to be converted into baffles.
# Analyzed problem cells in = 9.16 s
#
#
# Introducing baffles to delete problem cells.
#
# Edge intersection testing:
#     Number of edges             : 19321846
#     Number of edges to retest   : 8192713
#     Number of intersected edges : 2465113
# Created baffles in = 19.61 s
#
#
# After introducing baffles : cells:4891763  faces:19321846  points:5746120
# Cells per refinement level:
#     0	4891763
# Setting cellZones according to locationsInMesh:
# Location : (125 125 121)
#     cellZone : none
#
# For cellZone none found point (125 125 121) in global region 156 out of 1347127 regions.
# Edge intersection testing:
#     Number of edges             : 19321846
#     Number of edges to retest   : 8298201
#     Number of intersected edges : 2465113
#
# Remove unreachable sections of mesh
# -----------------------------------
#
# Keeping all cells containing points 1((125 125 121))
# Selected for keeping : 3517478 cells.
# Edge intersection testing:
#     Number of edges             : 11127869
#     Number of edges to retest   : 0
#     Number of intersected edges : 1060701
# Split mesh in = 39.47 s
#
#
# After subsetting : cells:3517478  faces:11127869  points:4104725
# Cells per refinement level:
#     0	3517478
#
# Introducing zones for interfaces
# --------------------------------
#
# Setting cellZones according to locationsInMesh:
# Location : (125 125 121)
#     cellZone : none
#
# For cellZone none found point (125 125 121) in global region 0 out of 1 regions.
# Setting faceZones according to neighbouring cellZones:
#
# Edge intersection testing:
#     Number of edges             : 11127869
#     Number of edges to retest   : 0
#     Number of intersected edges : 1060701
#
# Handling cells with snap problems
# ---------------------------------
#
# Introducing baffles for 1060701 faces that are intersected by the surface.
#
# Setting cellZones according to locationsInMesh:
# Location : (125 125 121)
#     cellZone : none
#
# For cellZone none found point (125 125 121) in global region 0 out of 1 regions.
# Edge intersection testing:
#     Number of edges             : 11127869
#     Number of edges to retest   : 2829570
#     Number of intersected edges : 1060701
# Created baffles in = 22.22 s
#
#
# After introducing baffles : cells:3517478  faces:11127869  points:4104725
# Cells per refinement level:
#     0	3517478
#
# Introducing baffles to block off problem cells
# ----------------------------------------------
#
# markFacesOnProblemCells : marked 749 additional internal faces to be converted into baffles.
# Analyzed problem cells in = 5.95 s
#
#
# Introducing baffles to delete problem cells.
#
# Edge intersection testing:
#     Number of edges             : 11128618
#     Number of edges to retest   : 3981
#     Number of intersected edges : 1060701
# Created baffles in = 5.79 s
#
#
# After introducing baffles : cells:3517478  faces:11128618  points:4104725
# Cells per refinement level:
#     0	3517478
# Setting cellZones according to locationsInMesh:
# Location : (125 125 121)
#     cellZone : none
#
# For cellZone none found point (125 125 121) in global region 0 out of 371 regions.
# Edge intersection testing:
#     Number of edges             : 11128618
#     Number of edges to retest   : 2830161
#     Number of intersected edges : 1060701
#
# Remove unreachable sections of mesh
# -----------------------------------
#
# Keeping all cells containing points 1((125 125 121))
# Selected for keeping : 3517087 cells.
# Edge intersection testing:
#     Number of edges             : 11126313
#     Number of edges to retest   : 0
#     Number of intersected edges : 1059841
# Split mesh in = 19.38 s
#
#
# After subsetting : cells:3517087  faces:11126313  points:4103889
# Cells per refinement level:
#     0	3517087
#
# Merge free-standing baffles
# ---------------------------
#
# freeStandingBaffles : detected 0 free-standing baffles out of 16
#
# Detected free-standing baffles : 0
# Merged free-standing baffles in = 1.97 s
#
#
# dupNonManifoldPoints : Found : 1097 non-manifold points (out of 4103889)
# Edge intersection testing:
#     Number of edges             : 11126313
#     Number of edges to retest   : 0
#     Number of intersected edges : 1059841
# Detected unsplittable baffles : 0
#
# Merge refined boundary faces
# ----------------------------
#
# Merging 0 sets of faces.
#
# No faces merged ...
#
# Merging all points on surface that
# - are used by only two boundary faces and
# - make an angle with a cosine of more than 0.707107.
#
# No straight edges simplified and no points removed ...
# Refined mesh : cells:3517087  faces:11126313  points:4104988
# Cells per refinement level:
#     0	3517087
# Writing mesh to time constant
# Wrote mesh in = 13.39 s.
# Mesh refined in = 223.51 s.
# Checking final mesh ...
# Checking faces in error :
#     non-orthogonality > 50  degrees                        : 0
#     faces with face pyramid volume < 1e-17                 : 0
#     faces with face-decomposition tet quality < 0.001      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with area < 1e-14 m^2                            : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces with triangle twist < 0.02                       : 0
#     faces on cells with determinant < 0.001                : 0
# Finished meshing without any errors
# Finished meshing in = 391.17 s.
# End
#
#
# >>> transformPoints -scale "(3.0035e-06 3.0035e-06 3.0035e-06)"
#
# /*---------------------------------------------------------------------------*\
# | =========                 |                                                 |
# | \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox           |
# |  \\    /   O peration     | Version:  2412                                  |
# |   \\  /    A nd           | Website:  www.openfoam.com                      |
# |    \\/     M anipulation  |                                                 |
# \*---------------------------------------------------------------------------*/
# Build  : _e5c6ccc3-20250814 OPENFOAM=2412 patch=250814 version=2412
# Arch   : "LSB;label=32;scalar=64"
# Exec   : transformPoints -scale (3.0035e-06 3.0035e-06 3.0035e-06)
# Date   : Feb 04 2026
# Time   : 14:21:32
# Host   : e-10aux32876g5
# PID    : 271134
# I/O    : uncollated
# Case   : /home/h09435ap/porePermFoam/bentheimer
# nProcs : 1
# trapFpe: Floating point exception trapping enabled (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 5, maxFileModificationPolls 20)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# --> FOAM Warning :
#     From static Foam::IOstreamOption::compressionType Foam::IOstreamOption::compressionEnum(const Foam::word&, Foam::IOstreamOption::compressionType)
#     in file db/options/IOstreamOption.C at line 189
#     Unknown compression specifier 'uncompressed' using compression off
# Scaling points uniformly by 3.0035e-06
# Writing points into directory "constant/polyMesh"
#
#
# End
#
#
# >>> simpleFoam
#
# /*---------------------------------------------------------------------------*\
# | =========                 |                                                 |
# | \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox           |
# |  \\    /   O peration     | Version:  2412                                  |
# |   \\  /    A nd           | Website:  www.openfoam.com                      |
# |    \\/     M anipulation  |                                                 |
# \*---------------------------------------------------------------------------*/
# Build  : _e5c6ccc3-20250814 OPENFOAM=2412 patch=250814 version=2412
# Arch   : "LSB;label=32;scalar=64"
# Exec   : simpleFoam
# Date   : Feb 04 2026
# Time   : 14:21:41
# Host   : e-10aux32876g5
# PID    : 271154
# I/O    : uncollated
# Case   : /home/h09435ap/porePermFoam/bentheimer
# nProcs : 1
# trapFpe: Floating point exception trapping enabled (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 5, maxFileModificationPolls 20)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# --> FOAM Warning :
#     From static Foam::IOstreamOption::compressionType Foam::IOstreamOption::compressionEnum(const Foam::word&, Foam::IOstreamOption::compressionType)
#     in file db/options/IOstreamOption.C at line 189
#     Unknown compression specifier 'uncompressed' using compression off
# Create mesh for time = 0
#
#
# SIMPLE: no convergence criteria found. Calculations will run for 5e-05 steps.
#
# Reading field p
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type laminar
# Selecting laminar stress model Stokes
# No MRF models present
#
# No finite volume options present
#
# Starting time loop
#
# Time = 1e-06
#
# smoothSolver:  Solving for Ux, Initial residual = 1, Final residual = 0.0793947, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0, Final residual = 0, No Iterations 0
# smoothSolver:  Solving for Uz, Initial residual = 0, Final residual = 0, No Iterations 0
# GAMG:  Solving for p, Initial residual = 1, Final residual = 0.00612506, No Iterations 6
# time step continuity errors : sum local = 1.82318e-08, global = -2.03204e-09, cumulative = -2.03204e-09
# ExecutionTime = 37.37 s  ClockTime = 38 s
#
# Time = 2e-06
#
# smoothSolver:  Solving for Ux, Initial residual = 0.500795, Final residual = 0.0424953, No Iterations 5
# smoothSolver:  Solving for Uy, Initial residual = 0.447959, Final residual = 0.043536, No Iterations 5
# smoothSolver:  Solving for Uz, Initial residual = 0.468374, Final residual = 0.0431154, No Iterations 5
# GAMG:  Solving for p, Initial residual = 0.113873, Final residual = 0.00101215, No Iterations 4
# time step continuity errors : sum local = 1.69371e-08, global = 3.10145e-09, cumulative = 1.06941e-09
# ExecutionTime = 46.96 s  ClockTime = 47 s
#
# Time = 3e-06
#
# smoothSolver:  Solving for Ux, Initial residual = 0.329888, Final residual = 0.0327409, No Iterations 5
# smoothSolver:  Solving for Uy, Initial residual = 0.236703, Final residual = 0.0234334, No Iterations 7
# smoothSolver:  Solving for Uz, Initial residual = 0.256205, Final residual = 0.0249252, No Iterations 7
# GAMG:  Solving for p, Initial residual = 0.0725466, Final residual = 0.000559919, No Iterations 4
# time step continuity errors : sum local = 1.08717e-08, global = -1.01798e-09, cumulative = 5.14258e-11
# ExecutionTime = 56.79 s  ClockTime = 57 s
#
# Time = 4e-06
#
# smoothSolver:  Solving for Ux, Initial residual = 0.237189, Final residual = 0.0188744, No Iterations 6
# smoothSolver:  Solving for Uy, Initial residual = 0.146114, Final residual = 0.0139972, No Iterations 8
# smoothSolver:  Solving for Uz, Initial residual = 0.164069, Final residual = 0.0158166, No Iterations 8
# GAMG:  Solving for p, Initial residual = 0.059124, Final residual = 0.000536237, No Iterations 4
# time step continuity errors : sum local = 1.03858e-08, global = -1.30533e-09, cumulative = -1.2539e-09
# ExecutionTime = 67.01 s  ClockTime = 67 s
#
# Time = 5e-06
#
# smoothSolver:  Solving for Ux, Initial residual = 0.171827, Final residual = 0.0146196, No Iterations 6
# smoothSolver:  Solving for Uy, Initial residual = 0.103097, Final residual = 0.00871834, No Iterations 9
# smoothSolver:  Solving for Uz, Initial residual = 0.116624, Final residual = 0.010133, No Iterations 9
# GAMG:  Solving for p, Initial residual = 0.0499112, Final residual = 0.000312063, No Iterations 5
# time step continuity errors : sum local = 5.86745e-09, global = 1.76662e-09, cumulative = 5.12719e-10
# ExecutionTime = 77.62 s  ClockTime = 78 s
#
# Time = 6e-06
#
# smoothSolver:  Solving for Ux, Initial residual = 0.129427, Final residual = 0.011899, No Iterations 6
# smoothSolver:  Solving for Uy, Initial residual = 0.0817544, Final residual = 0.00688134, No Iterations 9
# smoothSolver:  Solving for Uz, Initial residual = 0.0908048, Final residual = 0.0079106, No Iterations 9
# GAMG:  Solving for p, Initial residual = 0.0428658, Final residual = 0.00026468, No Iterations 5
# time step continuity errors : sum local = 5.07696e-09, global = 1.53673e-09, cumulative = 2.04945e-09
# ExecutionTime = 88.34 s  ClockTime = 89 s
#
# Time = 7e-06
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0992918, Final residual = 0.00970828, No Iterations 6
# smoothSolver:  Solving for Uy, Initial residual = 0.0672626, Final residual = 0.0056372, No Iterations 9
# smoothSolver:  Solving for Uz, Initial residual = 0.0729236, Final residual = 0.0063105, No Iterations 9
# GAMG:  Solving for p, Initial residual = 0.0365534, Final residual = 0.000204761, No Iterations 5
# time step continuity errors : sum local = 4.12488e-09, global = 1.22523e-09, cumulative = 3.27468e-09
# ExecutionTime = 99.01 s  ClockTime = 99 s
#
# Time = 8e-06
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0790354, Final residual = 0.00642048, No Iterations 7
# smoothSolver:  Solving for Uy, Initial residual = 0.0557911, Final residual = 0.00472621, No Iterations 9
# smoothSolver:  Solving for Uz, Initial residual = 0.0598021, Final residual = 0.0051946, No Iterations 9
# GAMG:  Solving for p, Initial residual = 0.0313342, Final residual = 0.000311004, No Iterations 4
# time step continuity errors : sum local = 6.50232e-09, global = -1.36677e-09, cumulative = 1.90791e-09
# ExecutionTime = 109.35 s  ClockTime = 110 s
#
# Time = 9e-06
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0637626, Final residual = 0.00525313, No Iterations 7
# smoothSolver:  Solving for Uy, Initial residual = 0.0471645, Final residual = 0.00409184, No Iterations 9
# smoothSolver:  Solving for Uz, Initial residual = 0.050223, Final residual = 0.00446525, No Iterations 9
# GAMG:  Solving for p, Initial residual = 0.0269377, Final residual = 0.000246395, No Iterations 4
# time step continuity errors : sum local = 5.30571e-09, global = -1.10885e-09, cumulative = 7.99063e-10
# ExecutionTime = 119.61 s  ClockTime = 120 s
#
# Time = 1e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.052604, Final residual = 0.00446488, No Iterations 7
# smoothSolver:  Solving for Uy, Initial residual = 0.039975, Final residual = 0.00353732, No Iterations 9
# smoothSolver:  Solving for Uz, Initial residual = 0.0428097, Final residual = 0.00387416, No Iterations 9
# GAMG:  Solving for p, Initial residual = 0.0233743, Final residual = 0.00021172, No Iterations 3
# time step continuity errors : sum local = 4.67177e-09, global = 2.28466e-09, cumulative = 3.08372e-09
# ExecutionTime = 140.06 s  ClockTime = 140 s
#
# Time = 1.1e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0443232, Final residual = 0.00390748, No Iterations 7
# smoothSolver:  Solving for Uy, Initial residual = 0.0344622, Final residual = 0.0031089, No Iterations 9
# smoothSolver:  Solving for Uz, Initial residual = 0.0367199, Final residual = 0.0033994, No Iterations 9
# GAMG:  Solving for p, Initial residual = 0.0204878, Final residual = 0.000105234, No Iterations 5
# time step continuity errors : sum local = 2.37248e-09, global = 7.27968e-10, cumulative = 3.81169e-09
# ExecutionTime = 150.84 s  ClockTime = 151 s
#
# Time = 1.2e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.037359, Final residual = 0.00333001, No Iterations 7
# smoothSolver:  Solving for Uy, Initial residual = 0.0298904, Final residual = 0.00267459, No Iterations 9
# smoothSolver:  Solving for Uz, Initial residual = 0.032289, Final residual = 0.00297999, No Iterations 9
# GAMG:  Solving for p, Initial residual = 0.017971, Final residual = 0.000176892, No Iterations 3
# time step continuity errors : sum local = 4.04939e-09, global = 1.88197e-09, cumulative = 5.69365e-09
# ExecutionTime = 160.89 s  ClockTime = 161 s
#
# Time = 1.3e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0317515, Final residual = 0.00292603, No Iterations 7
# smoothSolver:  Solving for Uy, Initial residual = 0.0259061, Final residual = 0.00238386, No Iterations 9
# smoothSolver:  Solving for Uz, Initial residual = 0.0278967, Final residual = 0.0026481, No Iterations 9
# GAMG:  Solving for p, Initial residual = 0.0157747, Final residual = 0.000142425, No Iterations 4
# time step continuity errors : sum local = 3.31065e-09, global = -5.35954e-10, cumulative = 5.1577e-09
# ExecutionTime = 170.95 s  ClockTime = 171 s
#
# Time = 1.4e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0272283, Final residual = 0.00255648, No Iterations 7
# smoothSolver:  Solving for Uy, Initial residual = 0.0228202, Final residual = 0.0020898, No Iterations 9
# smoothSolver:  Solving for Uz, Initial residual = 0.0248425, Final residual = 0.00235585, No Iterations 9
# GAMG:  Solving for p, Initial residual = 0.0138472, Final residual = 0.000116394, No Iterations 4
# time step continuity errors : sum local = 2.73992e-09, global = -5.19781e-10, cumulative = 4.63792e-09
# ExecutionTime = 181.23 s  ClockTime = 182 s
#
# Time = 1.5e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0234627, Final residual = 0.00227094, No Iterations 7
# smoothSolver:  Solving for Uy, Initial residual = 0.0200245, Final residual = 0.00187021, No Iterations 9
# smoothSolver:  Solving for Uz, Initial residual = 0.0219127, Final residual = 0.00210872, No Iterations 9
# GAMG:  Solving for p, Initial residual = 0.0121654, Final residual = 0.000100901, No Iterations 3
# time step continuity errors : sum local = 2.40318e-09, global = 1.11291e-09, cumulative = 5.75083e-09
# ExecutionTime = 191.24 s  ClockTime = 192 s
#
# Time = 1.6e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0205133, Final residual = 0.00165134, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0178756, Final residual = 0.00169515, No Iterations 9
# smoothSolver:  Solving for Uz, Initial residual = 0.0194532, Final residual = 0.00190435, No Iterations 9
# GAMG:  Solving for p, Initial residual = 0.0107216, Final residual = 0.000100111, No Iterations 4
# time step continuity errors : sum local = 2.41038e-09, global = -4.56352e-10, cumulative = 5.29448e-09
# ExecutionTime = 201.69 s  ClockTime = 202 s
#
# Time = 1.7e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0176967, Final residual = 0.00143356, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0161681, Final residual = 0.00152992, No Iterations 9
# smoothSolver:  Solving for Uz, Initial residual = 0.017764, Final residual = 0.00174025, No Iterations 9
# GAMG:  Solving for p, Initial residual = 0.00943411, Final residual = 7.57786e-05, No Iterations 4
# time step continuity errors : sum local = 1.83918e-09, global = -3.37395e-10, cumulative = 4.95708e-09
# ExecutionTime = 212.21 s  ClockTime = 212 s
#
# Time = 1.8e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0153897, Final residual = 0.00128063, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0144205, Final residual = 0.00138895, No Iterations 9
# smoothSolver:  Solving for Uz, Initial residual = 0.0159949, Final residual = 0.00158958, No Iterations 9
# GAMG:  Solving for p, Initial residual = 0.00831247, Final residual = 7.40184e-05, No Iterations 3
# time step continuity errors : sum local = 1.80935e-09, global = 7.73587e-10, cumulative = 5.73067e-09
# ExecutionTime = 222.42 s  ClockTime = 223 s
#
# Time = 1.9e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0135755, Final residual = 0.00116693, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0129879, Final residual = 0.00127027, No Iterations 9
# smoothSolver:  Solving for Uz, Initial residual = 0.0143772, Final residual = 0.00116654, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00734527, Final residual = 6.83909e-05, No Iterations 4
# time step continuity errors : sum local = 1.68272e-09, global = -2.96522e-10, cumulative = 5.43414e-09
# ExecutionTime = 233.07 s  ClockTime = 233 s
#
# Time = 2e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0119381, Final residual = 0.0010434, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0117751, Final residual = 0.00114746, No Iterations 9
# smoothSolver:  Solving for Uz, Initial residual = 0.0130599, Final residual = 0.00105636, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00648921, Final residual = 5.30562e-05, No Iterations 4
# time step continuity errors : sum local = 1.31168e-09, global = -2.25491e-10, cumulative = 5.20865e-09
# ExecutionTime = 254.13 s  ClockTime = 254 s
#
# Time = 2.1e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0105397, Final residual = 0.000948983, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0106042, Final residual = 0.00105124, No Iterations 9
# smoothSolver:  Solving for Uz, Initial residual = 0.0117614, Final residual = 0.000960917, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00576526, Final residual = 5.46902e-05, No Iterations 3
# time step continuity errors : sum local = 1.35788e-09, global = 5.5174e-10, cumulative = 5.76039e-09
# ExecutionTime = 264.27 s  ClockTime = 265 s
#
# Time = 2.2e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00942439, Final residual = 0.000873186, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.00962797, Final residual = 0.000778537, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.0106283, Final residual = 0.000881172, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00516284, Final residual = 4.72005e-05, No Iterations 4
# time step continuity errors : sum local = 1.17658e-09, global = -1.99927e-10, cumulative = 5.56047e-09
# ExecutionTime = 274.76 s  ClockTime = 275 s
#
# Time = 2.3e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00840468, Final residual = 0.000791151, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.00871463, Final residual = 0.000870119, No Iterations 9
# smoothSolver:  Solving for Uz, Initial residual = 0.00980361, Final residual = 0.000812047, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00462359, Final residual = 3.73524e-05, No Iterations 4
# time step continuity errors : sum local = 9.33793e-10, global = -1.57898e-10, cumulative = 5.40257e-09
# ExecutionTime = 285.36 s  ClockTime = 286 s
#
# Time = 2.4e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00750595, Final residual = 0.000721159, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.00794848, Final residual = 0.000649829, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00893403, Final residual = 0.000748632, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00414509, Final residual = 4.12653e-05, No Iterations 3
# time step continuity errors : sum local = 1.03433e-09, global = 3.96454e-10, cumulative = 5.79902e-09
# ExecutionTime = 295.47 s  ClockTime = 296 s
#
# Time = 2.5e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00679185, Final residual = 0.000668962, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.00720784, Final residual = 0.000595363, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00815421, Final residual = 0.000693213, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.0037204, Final residual = 3.30861e-05, No Iterations 4
# time step continuity errors : sum local = 8.31383e-10, global = -1.31305e-10, cumulative = 5.66772e-09
# ExecutionTime = 306.24 s  ClockTime = 307 s
#
# Time = 2.6e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00609832, Final residual = 0.000608452, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.00660405, Final residual = 0.000543626, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00757551, Final residual = 0.000643426, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00333921, Final residual = 2.69131e-05, No Iterations 4
# time step continuity errors : sum local = 6.77493e-10, global = -1.09919e-10, cumulative = 5.5578e-09
# ExecutionTime = 316.55 s  ClockTime = 317 s
#
# Time = 2.7e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00550035, Final residual = 0.000450792, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0.00602189, Final residual = 0.000502261, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00695351, Final residual = 0.000597157, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00299827, Final residual = 2.39092e-05, No Iterations 4
# time step continuity errors : sum local = 6.02878e-10, global = -1.11608e-10, cumulative = 5.44619e-09
# ExecutionTime = 327.16 s  ClockTime = 327 s
#
# Time = 2.8e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00494563, Final residual = 0.000410474, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0.00556974, Final residual = 0.000469935, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00644367, Final residual = 0.000558854, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00268904, Final residual = 2.07897e-05, No Iterations 4
# time step continuity errors : sum local = 5.24989e-10, global = -9.53155e-11, cumulative = 5.35088e-09
# ExecutionTime = 337.81 s  ClockTime = 338 s
#
# Time = 2.9e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00447124, Final residual = 0.00037667, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0.00513421, Final residual = 0.000436341, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00597581, Final residual = 0.00052235, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00241313, Final residual = 1.86775e-05, No Iterations 4
# time step continuity errors : sum local = 4.72266e-10, global = -8.24973e-11, cumulative = 5.26838e-09
# ExecutionTime = 348.34 s  ClockTime = 349 s
#
# Time = 3e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00405595, Final residual = 0.000347111, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0.00473044, Final residual = 0.000404645, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00554004, Final residual = 0.000487453, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00216621, Final residual = 1.70283e-05, No Iterations 4
# time step continuity errors : sum local = 4.31059e-10, global = -7.16904e-11, cumulative = 5.19669e-09
# ExecutionTime = 369.53 s  ClockTime = 370 s
#
# Time = 3.1e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0036886, Final residual = 0.00032072, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0.00436434, Final residual = 0.000375625, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00513822, Final residual = 0.000454783, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00194482, Final residual = 1.55634e-05, No Iterations 4
# time step continuity errors : sum local = 3.94367e-10, global = -6.31827e-11, cumulative = 5.13351e-09
# ExecutionTime = 380.03 s  ClockTime = 380 s
#
# Time = 3.2e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00336121, Final residual = 0.000296863, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0.00403218, Final residual = 0.000349152, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00476983, Final residual = 0.000424616, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00174623, Final residual = 1.41938e-05, No Iterations 4
# time step continuity errors : sum local = 3.59969e-10, global = -5.62197e-11, cumulative = 5.07729e-09
# ExecutionTime = 390.9 s  ClockTime = 391 s
#
# Time = 3.3e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00306826, Final residual = 0.000275164, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0.00373021, Final residual = 0.000324948, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00443328, Final residual = 0.000396916, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00156812, Final residual = 1.29251e-05, No Iterations 4
# time step continuity errors : sum local = 3.28037e-10, global = -5.02237e-11, cumulative = 5.02706e-09
# ExecutionTime = 401.68 s  ClockTime = 402 s
#
# Time = 3.4e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00280561, Final residual = 0.000255381, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0.00345531, Final residual = 0.000302772, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00412632, Final residual = 0.0003715, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00140838, Final residual = 1.17761e-05, No Iterations 4
# time step continuity errors : sum local = 2.99071e-10, global = -4.48945e-11, cumulative = 4.98217e-09
# ExecutionTime = 412.45 s  ClockTime = 413 s
#
# Time = 3.5e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00256976, Final residual = 0.000237313, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0.00320476, Final residual = 0.00028243, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00384616, Final residual = 0.000348143, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00126518, Final residual = 1.07536e-05, No Iterations 4
# time step continuity errors : sum local = 2.73258e-10, global = -4.01191e-11, cumulative = 4.94205e-09
# ExecutionTime = 423.26 s  ClockTime = 424 s
#
# Time = 3.6e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00235763, Final residual = 0.000220779, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0.00297616, Final residual = 0.000263739, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00358979, Final residual = 0.000326607, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00113698, Final residual = 9.85078e-06, No Iterations 4
# time step continuity errors : sum local = 2.50441e-10, global = -3.58819e-11, cumulative = 4.90617e-09
# ExecutionTime = 434.03 s  ClockTime = 434 s
#
# Time = 3.7e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00216652, Final residual = 0.000205621, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0.00276721, Final residual = 0.000246537, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00335457, Final residual = 0.000306691, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00102242, Final residual = 9.05507e-06, No Iterations 4
# time step continuity errors : sum local = 2.30313e-10, global = -3.22058e-11, cumulative = 4.87396e-09
# ExecutionTime = 444.9 s  ClockTime = 445 s
#
# Time = 3.8e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00199401, Final residual = 0.000191702, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0.00257593, Final residual = 0.000230681, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00313821, Final residual = 0.00028823, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.000919805, Final residual = 8.35101e-06, No Iterations 4
# time step continuity errors : sum local = 2.12489e-10, global = -2.90611e-11, cumulative = 4.8449e-09
# ExecutionTime = 455.72 s  ClockTime = 456 s
#
# Time = 3.9e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00183798, Final residual = 0.000178898, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0.00240052, Final residual = 0.000216037, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00293882, Final residual = 0.000271089, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.000827793, Final residual = 7.72486e-06, No Iterations 4
# time step continuity errors : sum local = 1.96626e-10, global = -2.63912e-11, cumulative = 4.81851e-09
# ExecutionTime = 466.48 s  ClockTime = 467 s
#
# Time = 4e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00169661, Final residual = 0.000167106, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0.00223935, Final residual = 0.000202492, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00275475, Final residual = 0.000255158, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00074522, Final residual = 7.16616e-06, No Iterations 4
# time step continuity errors : sum local = 1.82464e-10, global = -2.41327e-11, cumulative = 4.79438e-09
# ExecutionTime = 487.73 s  ClockTime = 488 s
#
# Time = 4.1e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00156831, Final residual = 0.000156227, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0.00209106, Final residual = 0.000189948, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00258465, Final residual = 0.000240333, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.000671091, Final residual = 6.66723e-06, No Iterations 4
# time step continuity errors : sum local = 1.69808e-10, global = -2.22273e-11, cumulative = 4.77215e-09
# ExecutionTime = 498.34 s  ClockTime = 499 s
#
# Time = 4.2e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00145168, Final residual = 0.000117829, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.0019544, Final residual = 0.000178314, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00242717, Final residual = 0.000226522, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.000605454, Final residual = 4.50407e-06, No Iterations 5
# time step continuity errors : sum local = 1.14743e-10, global = 3.75755e-11, cumulative = 4.80972e-09
# ExecutionTime = 509.86 s  ClockTime = 510 s
#
# Time = 4.3e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00134181, Final residual = 0.000109523, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00184672, Final residual = 0.000168917, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00230344, Final residual = 0.000215061, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.000544556, Final residual = 3.74141e-06, No Iterations 5
# time step continuity errors : sum local = 9.53346e-11, global = 3.17189e-11, cumulative = 4.84144e-09
# ExecutionTime = 521.08 s  ClockTime = 521 s
#
# Time = 4.4e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00123888, Final residual = 0.000101966, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00172878, Final residual = 0.000158957, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00216603, Final residual = 0.00020347, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.000490791, Final residual = 4.90086e-06, No Iterations 4
# time step continuity errors : sum local = 1.24902e-10, global = -1.72375e-11, cumulative = 4.82421e-09
# ExecutionTime = 531.95 s  ClockTime = 532 s
#
# Time = 4.5e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00114696, Final residual = 9.53867e-05, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00161622, Final residual = 0.000149491, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00203174, Final residual = 0.000192045, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.000443482, Final residual = 3.64878e-06, No Iterations 5
# time step continuity errors : sum local = 9.30078e-11, global = 2.99936e-11, cumulative = 4.8542e-09
# ExecutionTime = 543.19 s  ClockTime = 544 s
#
# Time = 4.6e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00107065, Final residual = 8.96324e-05, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00151889, Final residual = 0.000140635, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.0019221, Final residual = 0.000181434, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00039959, Final residual = 3.19859e-06, No Iterations 5
# time step continuity errors : sum local = 8.15453e-11, global = 2.69203e-11, cumulative = 4.88112e-09
# ExecutionTime = 554.49 s  ClockTime = 555 s
#
# Time = 4.7e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00099408, Final residual = 8.39364e-05, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00142372, Final residual = 0.000132394, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00180865, Final residual = 0.000171394, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00036084, Final residual = 2.92854e-06, No Iterations 5
# time step continuity errors : sum local = 7.46707e-11, global = 2.46386e-11, cumulative = 4.90576e-09
# ExecutionTime = 565.81 s  ClockTime = 566 s
#
# Time = 4.8e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.000925622, Final residual = 7.87816e-05, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00133568, Final residual = 0.000124686, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00170387, Final residual = 0.00016197, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.000326336, Final residual = 2.75799e-06, No Iterations 5
# time step continuity errors : sum local = 7.03304e-11, global = 2.31059e-11, cumulative = 4.92886e-09
# ExecutionTime = 577 s  ClockTime = 577 s
#
# Time = 4.9e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.000863198, Final residual = 7.40076e-05, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00125427, Final residual = 0.000117484, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00160698, Final residual = 0.000153154, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.000295309, Final residual = 2.63813e-06, No Iterations 5
# time step continuity errors : sum local = 6.72814e-11, global = 2.20274e-11, cumulative = 4.95089e-09
# ExecutionTime = 588.24 s  ClockTime = 589 s
#
# Time = 5e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.000805934, Final residual = 6.95685e-05, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00117895, Final residual = 0.00011076, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00151714, Final residual = 0.000144906, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.000267387, Final residual = 2.52922e-06, No Iterations 5
# time step continuity errors : sum local = 6.45101e-11, global = 2.1067e-11, cumulative = 4.97196e-09
# ExecutionTime = 610.12 s  ClockTime = 611 s
#
# End
#
#
# >>> postProcess -func 'flowRatePatch(name=inlet)'
#
# /*---------------------------------------------------------------------------*\
# | =========                 |                                                 |
# | \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox           |
# |  \\    /   O peration     | Version:  2412                                  |
# |   \\  /    A nd           | Website:  www.openfoam.com                      |
# |    \\/     M anipulation  |                                                 |
# \*---------------------------------------------------------------------------*/
# Build  : _e5c6ccc3-20250814 OPENFOAM=2412 patch=250814 version=2412
# Arch   : "LSB;label=32;scalar=64"
# Exec   : postProcess -func flowRatePatch(name=inlet)
# Date   : Feb 04 2026
# Time   : 14:31:52
# Host   : e-10aux32876g5
# PID    : 272424
# I/O    : uncollated
# Case   : /home/h09435ap/porePermFoam/bentheimer
# nProcs : 1
# trapFpe: Floating point exception trapping enabled (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 5, maxFileModificationPolls 20)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# --> FOAM Warning :
#     From static Foam::IOstreamOption::compressionType Foam::IOstreamOption::compressionEnum(const Foam::word&, Foam::IOstreamOption::compressionType)
#     in file db/options/IOstreamOption.C at line 189
#     Unknown compression specifier 'uncompressed' using compression off
# Create mesh for time = 0
#
# surfaceFieldValue flowRatePatch(name=inlet):
#     operation     = sum
#
#
# Time = 0
# --> FOAM Warning :
#     From virtual bool Foam::functionObjects::fieldSelection::checkSelection()
#     in file functionObjects/fieldSelections/fieldSelection/fieldSelection.C at line 179
#     Field phi not found
#
# Reading fields:
#
# Executing functionObjects
# surfaceFieldValue flowRatePatch(name=inlet) write:
#     total faces   = 12211
#     total area    = 1.09276e-07
#
# --> FOAM Warning :
#     From Foam::label Foam::functionObjects::fieldValues::surfaceFieldValue::writeAll(const vectorField&, const Foam::Field<Type>&, const pointField&, const faceList&) [with WeightType = double; Foam::label = int; Foam::vectorField = Foam::Field<Foam::Vector<double> >; Foam::pointField = Foam::Field<Foam::Vector<double> >; Foam::faceList = Foam::List<Foam::face>]
#     in file fieldValues/surfaceFieldValue/surfaceFieldValueTemplates.C at line 384
#     Requested field phi not found in database and not processed
#
#
# Time = 1e-05
#
# Reading fields:
#     surfaceScalarField: phi
#
# Executing functionObjects
# surfaceFieldValue flowRatePatch(name=inlet) write:
#     sum(inlet) of phi = -2.00731e-12
#
#
# Time = 2e-05
#
# Reading fields:
#     surfaceScalarField: phi
#
# Executing functionObjects
# surfaceFieldValue flowRatePatch(name=inlet) write:
#     sum(inlet) of phi = -3.00524e-12
#
#
# Time = 3e-05
#
# Reading fields:
#     surfaceScalarField: phi
#
# Executing functionObjects
# surfaceFieldValue flowRatePatch(name=inlet) write:
#     sum(inlet) of phi = -3.3443e-12
#
#
# Time = 4e-05
#
# Reading fields:
#     surfaceScalarField: phi
#
# Executing functionObjects
# surfaceFieldValue flowRatePatch(name=inlet) write:
#     sum(inlet) of phi = -3.5117e-12
#
#
# Time = 5e-05
#
# Reading fields:
#     surfaceScalarField: phi
#
# Executing functionObjects
# surfaceFieldValue flowRatePatch(name=inlet) write:
#     sum(inlet) of phi = -3.59608e-12
#
#
# End
#
#
# >>> postProcess -func 'flowRatePatch(name=outlet)'
#
# /*---------------------------------------------------------------------------*\
# | =========                 |                                                 |
# | \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox           |
# |  \\    /   O peration     | Version:  2412                                  |
# |   \\  /    A nd           | Website:  www.openfoam.com                      |
# |    \\/     M anipulation  |                                                 |
# \*---------------------------------------------------------------------------*/
# Build  : _e5c6ccc3-20250814 OPENFOAM=2412 patch=250814 version=2412
# Arch   : "LSB;label=32;scalar=64"
# Exec   : postProcess -func flowRatePatch(name=outlet)
# Date   : Feb 04 2026
# Time   : 14:32:30
# Host   : e-10aux32876g5
# PID    : 272509
# I/O    : uncollated
# Case   : /home/h09435ap/porePermFoam/bentheimer
# nProcs : 1
# trapFpe: Floating point exception trapping enabled (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 5, maxFileModificationPolls 20)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# --> FOAM Warning :
#     From static Foam::IOstreamOption::compressionType Foam::IOstreamOption::compressionEnum(const Foam::word&, Foam::IOstreamOption::compressionType)
#     in file db/options/IOstreamOption.C at line 189
#     Unknown compression specifier 'uncompressed' using compression off
# Create mesh for time = 0
#
# surfaceFieldValue flowRatePatch(name=outlet):
#     operation     = sum
#
#
# Time = 0
# --> FOAM Warning :
#     From virtual bool Foam::functionObjects::fieldSelection::checkSelection()
#     in file functionObjects/fieldSelections/fieldSelection/fieldSelection.C at line 179
#     Field phi not found
#
# Reading fields:
#
# Executing functionObjects
# surfaceFieldValue flowRatePatch(name=outlet) write:
#     total faces   = 16042
#     total area    = 1.4356e-07
#
# --> FOAM Warning :
#     From Foam::label Foam::functionObjects::fieldValues::surfaceFieldValue::writeAll(const vectorField&, const Foam::Field<Type>&, const pointField&, const faceList&) [with WeightType = double; Foam::label = int; Foam::vectorField = Foam::Field<Foam::Vector<double> >; Foam::pointField = Foam::Field<Foam::Vector<double> >; Foam::faceList = Foam::List<Foam::face>]
#     in file fieldValues/surfaceFieldValue/surfaceFieldValueTemplates.C at line 384
#     Requested field phi not found in database and not processed
#
#
# Time = 1e-05
#
# Reading fields:
#     surfaceScalarField: phi
#
# Executing functionObjects
# surfaceFieldValue flowRatePatch(name=outlet) write:
#     sum(outlet) of phi = 2.22243e-12
#
#
# Time = 2e-05
#
# Reading fields:
#     surfaceScalarField: phi
#
# Executing functionObjects
# surfaceFieldValue flowRatePatch(name=outlet) write:
#     sum(outlet) of phi = 2.98401e-12
#
#
# Time = 3e-05
#
# Reading fields:
#     surfaceScalarField: phi
#
# Executing functionObjects
# surfaceFieldValue flowRatePatch(name=outlet) write:
#     sum(outlet) of phi = 3.33755e-12
#
#
# Time = 4e-05
#
# Reading fields:
#     surfaceScalarField: phi
#
# Executing functionObjects
# surfaceFieldValue flowRatePatch(name=outlet) write:
#     sum(outlet) of phi = 3.50943e-12
#
#
# Time = 5e-05
#
# Reading fields:
#     surfaceScalarField: phi
#
# Executing functionObjects
# surfaceFieldValue flowRatePatch(name=outlet) write:
#     sum(outlet) of phi = 3.59807e-12
#
#
# End
#
# Warning: 6 times vs 5 rates for 'inlet'
# Warning: 6 times vs 5 rates for 'outlet'
# Wrote 5 records with area=1.09276e-07 to bentheimer/q_in.csv
# Wrote 5 records with area=1.4356e-07 to bentheimer/q_out.csv
#
# --- inlet fluxes ---
# t=0         , q_in=-2.00731e-12, A_in=1.09276e-07
# t=1e-05     , q_in=-3.00524e-12, A_in=1.09276e-07
# t=2e-05     , q_in=-3.34430e-12, A_in=1.09276e-07
# t=3e-05     , q_in=-3.51170e-12, A_in=1.09276e-07
# t=4e-05     , q_in=-3.59608e-12, A_in=1.09276e-07
#
# --- outlet fluxes ---
# t=0         , q_out=2.22243e-12, A_out=1.4356e-07
# t=1e-05     , q_out=2.98401e-12, A_out=1.4356e-07
# t=2e-05     , q_out=3.33755e-12, A_out=1.4356e-07
# t=3e-05     , q_out=3.50943e-12, A_out=1.4356e-07
# t=4e-05     , q_out=3.59807e-12, A_out=1.4356e-07

# %%
df_q_area = pd.read_csv(f"{sample}/q_in.csv")
df_q_area.head()
# Out:
#       time  flowRate_phi          area
# 0  0.00000 -2.007310e-12  1.092760e-07
# 1  0.00001 -3.005240e-12  1.092760e-07
# 2  0.00002 -3.344300e-12  1.092760e-07
# 3  0.00003 -3.511700e-12  1.092760e-07
# 4  0.00004 -3.596080e-12  1.092760e-07

# %%
phi = sft.vti_phi(vti_path)
print(f"Porosity: {phi:.02%}")

# Cross-sectional area
A = shape[1] * shape[2] * scale**2
miu = 1e-3  # fluid viscosity [Pa·s]
L = shape[0] * scale  # length [m]

# Flow rate from last timestep
Q = np.abs(df_q_area["flowRate_phi"].iloc[-1])

# Darcy's law
k = Q * miu * L / (A * dp)

print(f"Permeability: {k:.02e} m^2")
print(f"Permeability: {k * 1.01324997e15:.02f} md")
# Out:
# Porosity: 19.01%
# Permeability: 4.79e-12 m^2
# Permeability: 4852.64 md
