# %%
smpls = ["beadpack", "bentheimer", "berea", "doddington", "estaillades", "gildehauser", "ketton", "portland"]
sizes = [2e-6, 3.0035e-6, 2.7745e-6, 2.6929e-6, 3.31136e-6, 4.4e-6, 3.00006e-6, 4.525e-6]
sample = smpls[0]  # choose sample
size = sizes[0]    # choose size

# %%
import simpleFoam_tools as sft
import pandas as pd
import numpy as np

# %%
remove = 1
if remove:
    sft.remove_run_files(f"{sample}")

# %%
domain_name = f"{sample}_z"  # "cylinder" or "vti_bent_x"

scale = size  # voxel size [m]
dp = 1.0           # pressure difference [Pa]
refinement = 3   # local refinement level
factor_mesh_x = 1.0    # global mesh scale factor
factor_mesh_y = 1.0    # global mesh scale factor
factor_mesh_z = 1.0    # global mesh scale factor

boundary_type = "Wall"  # "symmetryPlane" or "Wall"

dt = 1e-6
end_time = 50e-6
write_interval = 10

# %%
# Get voxel shape and a pore voxel location from VTI
vti_path = f"{sample}/constant/geometry/{domain_name}.vti"
shape = sft.vti_shape(vti_path)
location_in_mesh = sft.find_pore_location(vti_path)

# Convert VTI to STL surface mesh
stl = f"{domain_name}.stl"
stl_path = f"{sample}/constant/triSurface/{stl}"
sft.vti_to_stl(vti_path, stl_path)

# Adjust mesh resolution
mesh_resolution = (int(shape[0]*factor_mesh_x), int(shape[1]*factor_mesh_y), int(shape[2]*factor_mesh_z))

# File paths
blockMeshDict_path    = f"{sample}/system/blockMeshDict"
controlDict_path      = f"{sample}/system/controlDict"
p_field_path          = f"{sample}/0/p"
U_field_path          = f"{sample}/0/U"
snappyHexMeshDict_path = f"{sample}/system/snappyHexMeshDict"
# Generate OpenFOAM files
sft.generate_blockMeshDict(shape, mesh_resolution, blockMeshDict_path, boundary=boundary_type)
sft.generate_snappyHexMeshDict(location_in_mesh, stl, snappyHexMeshDict_path, refinement=refinement)
sft.generate_controlDict(controlDict_path, end_time=end_time, write_interval=write_interval, dt=dt)
sft.generate_pressure_field(p_field_path, dp=dp, boundary=boundary_type)
sft.generate_velocity_field(U_field_path, boundary=boundary_type)
# Out:
# Running command: pvpython /home/h09435ap/porePermFoam/simpleFoam_tools/paraview_stl.py /home/h09435ap/porePermFoam/beadpack/constant/geometry/beadpack_z.vti /home/h09435ap/porePermFoam/beadpack/constant/triSurface/beadpack_z.stl
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# ✅ Wrote ASCII STL: /home/h09435ap/porePermFoam/beadpack/constant/triSurface/beadpack_z.stl
# Generated blockMeshDict at: beadpack/system/blockMeshDict
# Generated snappyHexMeshDict at: beadpack/system/snappyHexMeshDict
# Generated controlDict at: beadpack/system/controlDict
# Generated p at: beadpack/0/p with boundary zeroGradient
# Generated U at: beadpack/0/U with boundary noSlip

# %%
sft.run_simplefoam(f"{sample}", scale=scale)
# Out:
# >>> blockMesh
#
# /*---------------------------------------------------------------------------*\
# | =========                 |                                                 |
# | \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox           |
# |  \\    /   O peration     | Version:  2412                                  |
# |   \\  /    A nd           | Website:  www.openfoam.com                      |
# |    \\/     M anipulation  |                                                 |
# \*---------------------------------------------------------------------------*/
# Build  : _e5c6ccc3-20250814 OPENFOAM=2412 patch=250814 version=2412
# Arch   : "LSB;label=32;scalar=64"
# Exec   : blockMesh
# Date   : Feb 04 2026
# Time   : 16:17:27
# Host   : e-10aux32876g5
# PID    : 288709
# I/O    : uncollated
# Case   : /home/h09435ap/porePermFoam/beadpack
# nProcs : 1
# trapFpe: Floating point exception trapping enabled (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 5, maxFileModificationPolls 20)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# --> FOAM Warning :
#     From static Foam::IOstreamOption::compressionType Foam::IOstreamOption::compressionEnum(const Foam::word&, Foam::IOstreamOption::compressionType)
#     in file db/options/IOstreamOption.C at line 189
#     Unknown compression specifier 'uncompressed' using compression off
# Creating block mesh from "system/blockMeshDict"
# Creating block edges
# No non-planar block faces defined
# Creating topology blocks
#
# Creating topology patches - from boundary section
#
# Creating block mesh topology
#
# Check topology
#
# 	Basic statistics
# 		Number of internal faces : 0
# 		Number of boundary faces : 6
# 		Number of defined boundary faces : 6
# 		Number of undefined boundary faces : 0
# 	Checking patch -> block consistency
#
# Creating block offsets
# Creating merge list (topological search)...
#
# Creating polyMesh from blockMesh
# Creating patches
# Creating cells
# Creating points with scale (1 1 1)
#     Block 0 cell size :
#         i : 0.996 .. 0.996
#         j : 0.996 .. 0.996
#         k : 0.996 .. 0.996
#
# No patch pairs to merge
#
# Writing polyMesh with 0 cellZones
# ----------------
# Mesh Information
# ----------------
#   boundingBox: (0 0 0) (249 249 249)
#   nPoints: 15813251
#   nCells: 15625000
#   nFaces: 47062500
#   nInternalFaces: 46687500
# ----------------
# Patches
# ----------------
#   patch 0 (start: 46687500 size: 62500) name: top
#   patch 1 (start: 46750000 size: 62500) name: inlet
#   patch 2 (start: 46812500 size: 62500) name: bottom
#   patch 3 (start: 46875000 size: 62500) name: outlet
#   patch 4 (start: 46937500 size: 62500) name: front
#   patch 5 (start: 47000000 size: 62500) name: back
#
# End
#
#
# >>> snappyHexMesh -overwrite
#
# /*---------------------------------------------------------------------------*\
# | =========                 |                                                 |
# | \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox           |
# |  \\    /   O peration     | Version:  2412                                  |
# |   \\  /    A nd           | Website:  www.openfoam.com                      |
# |    \\/     M anipulation  |                                                 |
# \*---------------------------------------------------------------------------*/
# Build  : _e5c6ccc3-20250814 OPENFOAM=2412 patch=250814 version=2412
# Arch   : "LSB;label=32;scalar=64"
# Exec   : snappyHexMesh -overwrite
# Date   : Feb 04 2026
# Time   : 16:19:10
# Host   : e-10aux32876g5
# PID    : 289269
# I/O    : uncollated
# Case   : /home/h09435ap/porePermFoam/beadpack
# nProcs : 1
# trapFpe: Floating point exception trapping enabled (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 5, maxFileModificationPolls 20)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# --> FOAM Warning :
#     From static Foam::IOstreamOption::compressionType Foam::IOstreamOption::compressionEnum(const Foam::word&, Foam::IOstreamOption::compressionType)
#     in file db/options/IOstreamOption.C at line 189
#     Unknown compression specifier 'uncompressed' using compression off
# Create mesh for time = 0
#
# Read mesh in = 77.91 s
#
# Overall mesh bounding box  : (0 0 0) (249 249 249)
# Relative tolerance         : 1e-06
# Absolute matching distance : 0.000431281
#
# Reading refinement surfaces.
# Read refinement surfaces in = 4.79 s
#
# Reading refinement shells.
# Read refinement shells in = 0 s
#
# Setting refinement level of surface to be consistent with shells.
# For geometry beadpack_z.stl detected 0 uncached triangles out of 3767688
# Checked shell refinement in = 12.49 s
#
# Reading features.
# Read features in = 0 s
#
#
# Determining initial surface intersections
# -----------------------------------------
#
# Edge intersection testing:
#     Number of edges             : 47062500
#     Number of edges to retest   : 0
#     Number of intersected edges : 0
# Edge intersection testing:
#     Number of edges             : 47062500
#     Number of edges to retest   : 47062500
#     Number of intersected edges : 1898528
# Calculated surface intersections in = 66.59 s
#
# Initial mesh : cells:15625000  faces:47062500  points:15813251
# Cells per refinement level:
#     0	15625000
# Setting refinement level of surface to be consistent with curvature.
# Checked curvature refinement in = 0.08 s
#
#
# Adding patches for surface regions
# ----------------------------------
#
# Patch Type                Region
# ----- ----                ------
# solids:
#
# 6     wall                solids
#
# Added patches in = 0.5 s
#
# Edge intersection testing:
#     Number of edges             : 47062500
#     Number of edges to retest   : 0
#     Number of intersected edges : 1898528
# Decomposition method none [1]
#
# Refinement phase
# ----------------
#
# Found point (134 123 131) in cell 8218384 on processor 0
#
# Surface refinement iteration 0
# ------------------------------
#
# No cells marked for refinement since reached limit 2000000.
# Determined cells to refine in = 12.76 s
# Selected for refinement : 0 cells (out of 15625000)
# Stopping refining since too few cells selected.
#
#
# Removing mesh beyond surface intersections
# ------------------------------------------
#
# Setting cellZones according to locationsInMesh:
# Location : (134 123 131)
#     cellZone : none
#
# For cellZone none found point (134 123 131) in global region 1 out of 23 regions.
# --> FOAM Warning :
#     From void Foam::meshRefinement::nearestFace(const labelUList&, const Foam::bitSet&, Foam::autoPtr<Foam::mapDistribute>&, Foam::labelList&, Foam::label) const
#     in file meshRefinement/meshRefinement.C at line 527
#     Did not visit some faces, e.g. face 228 at (76.692 0.498 0.498)
# Keeping all cells containing inside points
# Selected for keeping : 8271702 cells.
# Edge intersection testing:
#     Number of edges             : 25833028
#     Number of edges to retest   : 1660844
#     Number of intersected edges : 1898528
#
# Shell refinement iteration 0
# ----------------------------
#
# No cells marked for refinement since reached limit 2000000.
# Determined cells to refine in = 48.21 s
# Selected for internal refinement : 0 cells (out of 8271702)
# Stopping refining since too few cells selected.
#
#
# Dangling coarse cells refinement iteration 0
# --------------------------------------------
#
# Determined cells to refine in = 0.37 s
# Selected for refinement : 0 cells (out of 8271702)
# Stopping refining since too few cells selected.
#
#
# Dangling coarse cells refinement iteration 0
# --------------------------------------------
#
# Determined cells to refine in = 0.36 s
# Selected for refinement : 0 cells (out of 8271702)
# Stopping refining since too few cells selected.
#
#
# Refinement transition refinement iteration 0
# --------------------------------------------
#
# Determined cells to refine in = 0.43 s
# Selected for refinement : 0 cells (out of 8271702)
# Stopping refining since too few cells selected.
#
#
# Splitting mesh at surface intersections
# ---------------------------------------
#
# Introducing baffles for 1898528 faces that are intersected by the surface.
#
# Setting cellZones according to locationsInMesh:
# Location : (134 123 131)
#     cellZone : none
#
# For cellZone none found point (134 123 131) in global region 1 out of 23 regions.
# Edge intersection testing:
#     Number of edges             : 27513123
#     Number of edges to retest   : 9679639
#     Number of intersected edges : 3578623
# Created baffles in = 37 s
#
#
# After introducing baffles : cells:8271702  faces:27513123  points:9264425
# Cells per refinement level:
#     0	8271702
#
# Introducing baffles to block off problem cells
# ----------------------------------------------
#
# markFacesOnProblemCells : marked 3559965 additional internal faces to be converted into baffles.
# Analyzed problem cells in = 15.14 s
#
#
# Introducing baffles to delete problem cells.
#
# Edge intersection testing:
#     Number of edges             : 31073088
#     Number of edges to retest   : 10713821
#     Number of intersected edges : 3578623
# Created baffles in = 31.9 s
#
#
# After introducing baffles : cells:8271702  faces:31073088  points:9264425
# Cells per refinement level:
#     0	8271702
# Setting cellZones according to locationsInMesh:
# Location : (134 123 131)
#     cellZone : none
#
# For cellZone none found point (134 123 131) in global region 28 out of 1773769 regions.
# Edge intersection testing:
#     Number of edges             : 31073088
#     Number of edges to retest   : 11151390
#     Number of intersected edges : 3578623
#
# Remove unreachable sections of mesh
# -----------------------------------
#
# Keeping all cells containing points 1((134 123 131))
# Selected for keeping : 6478886 cells.
# Edge intersection testing:
#     Number of edges             : 20353535
#     Number of edges to retest   : 0
#     Number of intersected edges : 1674448
# Split mesh in = 66.88 s
#
#
# After subsetting : cells:6478886  faces:20353535  points:7385742
# Cells per refinement level:
#     0	6478886
#
# Introducing zones for interfaces
# --------------------------------
#
# Setting cellZones according to locationsInMesh:
# Location : (134 123 131)
#     cellZone : none
#
# For cellZone none found point (134 123 131) in global region 0 out of 1 regions.
# Setting faceZones according to neighbouring cellZones:
#
# Edge intersection testing:
#     Number of edges             : 20353535
#     Number of edges to retest   : 0
#     Number of intersected edges : 1674448
#
# Handling cells with snap problems
# ---------------------------------
#
# Introducing baffles for 1674448 faces that are intersected by the surface.
#
# Setting cellZones according to locationsInMesh:
# Location : (134 123 131)
#     cellZone : none
#
# For cellZone none found point (134 123 131) in global region 0 out of 1 regions.
# Edge intersection testing:
#     Number of edges             : 20353535
#     Number of edges to retest   : 4549394
#     Number of intersected edges : 1674448
# Created baffles in = 40.03 s
#
#
# After introducing baffles : cells:6478886  faces:20353535  points:7385742
# Cells per refinement level:
#     0	6478886
#
# Introducing baffles to block off problem cells
# ----------------------------------------------
#
# markFacesOnProblemCells : marked 1258 additional internal faces to be converted into baffles.
# Analyzed problem cells in = 10.72 s
#
#
# Introducing baffles to delete problem cells.
#
# Edge intersection testing:
#     Number of edges             : 20354793
#     Number of edges to retest   : 6923
#     Number of intersected edges : 1674448
# Created baffles in = 11.6 s
#
#
# After introducing baffles : cells:6478886  faces:20354793  points:7385742
# Cells per refinement level:
#     0	6478886
# Setting cellZones according to locationsInMesh:
# Location : (134 123 131)
#     cellZone : none
#
# For cellZone none found point (134 123 131) in global region 0 out of 545 regions.
# Edge intersection testing:
#     Number of edges             : 20354793
#     Number of edges to retest   : 4550575
#     Number of intersected edges : 1674448
#
# Remove unreachable sections of mesh
# -----------------------------------
#
# Keeping all cells containing points 1((134 123 131))
# Selected for keeping : 6478342 cells.
# Edge intersection testing:
#     Number of edges             : 20351529
#     Number of edges to retest   : 0
#     Number of intersected edges : 1673528
# Split mesh in = 35.37 s
#
#
# After subsetting : cells:6478342  faces:20351529  points:7384870
# Cells per refinement level:
#     0	6478342
#
# Merge free-standing baffles
# ---------------------------
#
# freeStandingBaffles : detected 0 free-standing baffles out of 3
#
# Detected free-standing baffles : 0
# Merged free-standing baffles in = 3.3 s
#
#
# dupNonManifoldPoints : Found : 114 non-manifold points (out of 7384870)
# Edge intersection testing:
#     Number of edges             : 20351529
#     Number of edges to retest   : 0
#     Number of intersected edges : 1673528
# Detected unsplittable baffles : 0
#
# Merge refined boundary faces
# ----------------------------
#
# Merging 0 sets of faces.
#
# No faces merged ...
#
# Merging all points on surface that
# - are used by only two boundary faces and
# - make an angle with a cosine of more than 0.707107.
#
# No straight edges simplified and no points removed ...
# Refined mesh : cells:6478342  faces:20351529  points:7384984
# Cells per refinement level:
#     0	6478342
# Writing mesh to time constant
# Wrote mesh in = 24.29 s.
# Mesh refined in = 360.77 s.
# Checking final mesh ...
# Checking faces in error :
#     non-orthogonality > 50  degrees                        : 0
#     faces with face pyramid volume < 1e-17                 : 0
#     faces with face-decomposition tet quality < 0.001      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with area < 1e-14 m^2                            : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces with triangle twist < 0.02                       : 0
#     faces on cells with determinant < 0.001                : 0
# Finished meshing without any errors
# Finished meshing in = 546.58 s.
# End
#
#
# >>> transformPoints -scale "(2e-06 2e-06 2e-06)"
#
# /*---------------------------------------------------------------------------*\
# | =========                 |                                                 |
# | \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox           |
# |  \\    /   O peration     | Version:  2412                                  |
# |   \\  /    A nd           | Website:  www.openfoam.com                      |
# |    \\/     M anipulation  |                                                 |
# \*---------------------------------------------------------------------------*/
# Build  : _e5c6ccc3-20250814 OPENFOAM=2412 patch=250814 version=2412
# Arch   : "LSB;label=32;scalar=64"
# Exec   : transformPoints -scale (2e-06 2e-06 2e-06)
# Date   : Feb 04 2026
# Time   : 16:28:18
# Host   : e-10aux32876g5
# PID    : 290984
# I/O    : uncollated
# Case   : /home/h09435ap/porePermFoam/beadpack
# nProcs : 1
# trapFpe: Floating point exception trapping enabled (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 5, maxFileModificationPolls 20)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# --> FOAM Warning :
#     From static Foam::IOstreamOption::compressionType Foam::IOstreamOption::compressionEnum(const Foam::word&, Foam::IOstreamOption::compressionType)
#     in file db/options/IOstreamOption.C at line 189
#     Unknown compression specifier 'uncompressed' using compression off
# Scaling points uniformly by 2e-06
# Writing points into directory "constant/polyMesh"
#
#
# End
#
#
# >>> simpleFoam
#
# /*---------------------------------------------------------------------------*\
# | =========                 |                                                 |
# | \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox           |
# |  \\    /   O peration     | Version:  2412                                  |
# |   \\  /    A nd           | Website:  www.openfoam.com                      |
# |    \\/     M anipulation  |                                                 |
# \*---------------------------------------------------------------------------*/
# Build  : _e5c6ccc3-20250814 OPENFOAM=2412 patch=250814 version=2412
# Arch   : "LSB;label=32;scalar=64"
# Exec   : simpleFoam
# Date   : Feb 04 2026
# Time   : 16:28:34
# Host   : e-10aux32876g5
# PID    : 291018
# I/O    : uncollated
# Case   : /home/h09435ap/porePermFoam/beadpack
# nProcs : 1
# trapFpe: Floating point exception trapping enabled (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 5, maxFileModificationPolls 20)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# --> FOAM Warning :
#     From static Foam::IOstreamOption::compressionType Foam::IOstreamOption::compressionEnum(const Foam::word&, Foam::IOstreamOption::compressionType)
#     in file db/options/IOstreamOption.C at line 189
#     Unknown compression specifier 'uncompressed' using compression off
# Create mesh for time = 0
#
#
# SIMPLE: no convergence criteria found. Calculations will run for 5e-05 steps.
#
# Reading field p
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type laminar
# Selecting laminar stress model Stokes
# No MRF models present
#
# No finite volume options present
#
# Starting time loop
#
# Time = 1e-06
#
# smoothSolver:  Solving for Ux, Initial residual = 1, Final residual = 0.0947612, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0, Final residual = 0, No Iterations 0
# smoothSolver:  Solving for Uz, Initial residual = 0, Final residual = 0, No Iterations 0
# GAMG:  Solving for p, Initial residual = 1, Final residual = 0.00514985, No Iterations 6
# time step continuity errors : sum local = 1.99152e-08, global = -1.7817e-09, cumulative = -1.7817e-09
# ExecutionTime = 68.38 s  ClockTime = 68 s
#
# Time = 2e-06
#
# smoothSolver:  Solving for Ux, Initial residual = 0.504993, Final residual = 0.0412084, No Iterations 6
# smoothSolver:  Solving for Uy, Initial residual = 0.45737, Final residual = 0.0445309, No Iterations 5
# smoothSolver:  Solving for Uz, Initial residual = 0.46593, Final residual = 0.0422317, No Iterations 5
# GAMG:  Solving for p, Initial residual = 0.123846, Final residual = 0.000868264, No Iterations 4
# time step continuity errors : sum local = 1.76295e-08, global = 2.30507e-09, cumulative = 5.23368e-10
# ExecutionTime = 89.23 s  ClockTime = 89 s
#
# Time = 3e-06
#
# smoothSolver:  Solving for Ux, Initial residual = 0.315414, Final residual = 0.0248148, No Iterations 7
# smoothSolver:  Solving for Uy, Initial residual = 0.251108, Final residual = 0.0250239, No Iterations 7
# smoothSolver:  Solving for Uz, Initial residual = 0.258932, Final residual = 0.0247607, No Iterations 7
# GAMG:  Solving for p, Initial residual = 0.0818332, Final residual = 0.000546457, No Iterations 4
# time step continuity errors : sum local = 1.24969e-08, global = -1.05222e-09, cumulative = -5.2885e-10
# ExecutionTime = 110.77 s  ClockTime = 111 s
#
# Time = 4e-06
#
# smoothSolver:  Solving for Ux, Initial residual = 0.216401, Final residual = 0.0186427, No Iterations 7
# smoothSolver:  Solving for Uy, Initial residual = 0.158812, Final residual = 0.0153154, No Iterations 8
# smoothSolver:  Solving for Uz, Initial residual = 0.164883, Final residual = 0.0155578, No Iterations 8
# GAMG:  Solving for p, Initial residual = 0.0684721, Final residual = 0.000503296, No Iterations 4
# time step continuity errors : sum local = 1.11664e-08, global = -1.54283e-09, cumulative = -2.07168e-09
# ExecutionTime = 132.54 s  ClockTime = 133 s
#
# Time = 5e-06
#
# smoothSolver:  Solving for Ux, Initial residual = 0.155576, Final residual = 0.0145439, No Iterations 7
# smoothSolver:  Solving for Uy, Initial residual = 0.111571, Final residual = 0.00951463, No Iterations 9
# smoothSolver:  Solving for Uz, Initial residual = 0.115594, Final residual = 0.00973928, No Iterations 9
# GAMG:  Solving for p, Initial residual = 0.0606095, Final residual = 0.000501669, No Iterations 4
# time step continuity errors : sum local = 1.02667e-08, global = -1.54029e-09, cumulative = -3.61197e-09
# ExecutionTime = 154.65 s  ClockTime = 155 s
#
# Time = 6e-06
#
# smoothSolver:  Solving for Ux, Initial residual = 0.11651, Final residual = 0.00935416, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0870714, Final residual = 0.00760119, No Iterations 9
# smoothSolver:  Solving for Uz, Initial residual = 0.089388, Final residual = 0.00772965, No Iterations 9
# GAMG:  Solving for p, Initial residual = 0.0548483, Final residual = 0.000451786, No Iterations 4
# time step continuity errors : sum local = 9.02071e-09, global = -1.5031e-09, cumulative = -5.11507e-09
# ExecutionTime = 176.84 s  ClockTime = 177 s
#
# Time = 7e-06
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0888451, Final residual = 0.00751924, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0721095, Final residual = 0.00636582, No Iterations 9
# smoothSolver:  Solving for Uz, Initial residual = 0.0732201, Final residual = 0.00637499, No Iterations 9
# GAMG:  Solving for p, Initial residual = 0.0465941, Final residual = 0.000458955, No Iterations 3
# time step continuity errors : sum local = 9.66821e-09, global = 4.52316e-09, cumulative = -5.91913e-10
# ExecutionTime = 198.46 s  ClockTime = 199 s
#
# Time = 8e-06
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0711418, Final residual = 0.00623225, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0600322, Final residual = 0.00540403, No Iterations 9
# smoothSolver:  Solving for Uz, Initial residual = 0.0605771, Final residual = 0.00536445, No Iterations 9
# GAMG:  Solving for p, Initial residual = 0.0395335, Final residual = 0.000330587, No Iterations 4
# time step continuity errors : sum local = 7.31485e-09, global = -1.11856e-09, cumulative = -1.71047e-09
# ExecutionTime = 220.69 s  ClockTime = 221 s
#
# Time = 9e-06
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0576731, Final residual = 0.00514613, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0502058, Final residual = 0.00460325, No Iterations 9
# smoothSolver:  Solving for Uz, Initial residual = 0.0510877, Final residual = 0.00459267, No Iterations 9
# GAMG:  Solving for p, Initial residual = 0.0335643, Final residual = 0.00031176, No Iterations 3
# time step continuity errors : sum local = 7.1721e-09, global = 3.1358e-09, cumulative = 1.42533e-09
# ExecutionTime = 242.19 s  ClockTime = 242 s
#
# Time = 1e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0480342, Final residual = 0.00440492, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0427064, Final residual = 0.00400248, No Iterations 9
# smoothSolver:  Solving for Uz, Initial residual = 0.0431311, Final residual = 0.00396904, No Iterations 9
# GAMG:  Solving for p, Initial residual = 0.0290381, Final residual = 0.000217003, No Iterations 4
# time step continuity errors : sum local = 5.14877e-09, global = -8.42069e-10, cumulative = 5.83262e-10
# ExecutionTime = 284.41 s  ClockTime = 285 s
#
# Time = 1.1e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0400179, Final residual = 0.00375799, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0365441, Final residual = 0.00348424, No Iterations 9
# smoothSolver:  Solving for Uz, Initial residual = 0.0372402, Final residual = 0.00347654, No Iterations 9
# GAMG:  Solving for p, Initial residual = 0.0253205, Final residual = 0.000201858, No Iterations 3
# time step continuity errors : sum local = 4.91166e-09, global = 2.24547e-09, cumulative = 2.82873e-09
# ExecutionTime = 305.83 s  ClockTime = 306 s
#
# Time = 1.2e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0341366, Final residual = 0.00327203, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0317772, Final residual = 0.00307939, No Iterations 9
# smoothSolver:  Solving for Uz, Initial residual = 0.0321148, Final residual = 0.00305626, No Iterations 9
# GAMG:  Solving for p, Initial residual = 0.0221387, Final residual = 0.000167353, No Iterations 4
# time step continuity errors : sum local = 4.15669e-09, global = -7.15184e-10, cumulative = 2.11355e-09
# ExecutionTime = 327.98 s  ClockTime = 328 s
#
# Time = 1.3e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0289339, Final residual = 0.00284119, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0278376, Final residual = 0.00272663, No Iterations 9
# smoothSolver:  Solving for Uz, Initial residual = 0.0283492, Final residual = 0.00271853, No Iterations 9
# GAMG:  Solving for p, Initial residual = 0.0193356, Final residual = 0.000157837, No Iterations 3
# time step continuity errors : sum local = 3.99348e-09, global = 1.68277e-09, cumulative = 3.79631e-09
# ExecutionTime = 349.39 s  ClockTime = 350 s
#
# Time = 1.4e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0250962, Final residual = 0.00250563, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0244794, Final residual = 0.00243891, No Iterations 9
# smoothSolver:  Solving for Uz, Initial residual = 0.0247721, Final residual = 0.0024214, No Iterations 9
# GAMG:  Solving for p, Initial residual = 0.0169563, Final residual = 0.000127171, No Iterations 4
# time step continuity errors : sum local = 3.27287e-09, global = -5.49114e-10, cumulative = 3.2472e-09
# ExecutionTime = 371.66 s  ClockTime = 372 s
#
# Time = 1.5e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0215762, Final residual = 0.00177569, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0.021749, Final residual = 0.0017437, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.0221764, Final residual = 0.00217665, No Iterations 9
# GAMG:  Solving for p, Initial residual = 0.0148523, Final residual = 0.000128597, No Iterations 3
# time step continuity errors : sum local = 3.36016e-09, global = 1.31565e-09, cumulative = 4.56285e-09
# ExecutionTime = 393.38 s  ClockTime = 394 s
#
# Time = 1.6e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0188351, Final residual = 0.00156983, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0.0193802, Final residual = 0.00157448, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.0197768, Final residual = 0.00197482, No Iterations 9
# GAMG:  Solving for p, Initial residual = 0.0130698, Final residual = 0.000102157, No Iterations 4
# time step continuity errors : sum local = 2.70339e-09, global = -4.40479e-10, cumulative = 4.12237e-09
# ExecutionTime = 415.9 s  ClockTime = 416 s
#
# Time = 1.7e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0163028, Final residual = 0.00138859, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0.0173739, Final residual = 0.00141731, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.0179969, Final residual = 0.00144146, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.0114844, Final residual = 9.98149e-05, No Iterations 3
# time step continuity errors : sum local = 2.67016e-09, global = 1.01887e-09, cumulative = 5.14125e-09
# ExecutionTime = 437.81 s  ClockTime = 438 s
#
# Time = 1.8e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0143668, Final residual = 0.00124281, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0.0155144, Final residual = 0.00128485, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.0158775, Final residual = 0.00129478, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.0101295, Final residual = 7.84087e-05, No Iterations 4
# time step continuity errors : sum local = 2.11655e-09, global = -3.39023e-10, cumulative = 4.80222e-09
# ExecutionTime = 460.55 s  ClockTime = 461 s
#
# Time = 1.9e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0125653, Final residual = 0.00111188, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0.0139961, Final residual = 0.00116374, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.0143611, Final residual = 0.00116991, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00892904, Final residual = 7.92992e-05, No Iterations 3
# time step continuity errors : sum local = 2.15719e-09, global = 8.00496e-10, cumulative = 5.60272e-09
# ExecutionTime = 482.54 s  ClockTime = 483 s
#
# Time = 2e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0111478, Final residual = 0.00100109, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0.0125861, Final residual = 0.00106114, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.0128174, Final residual = 0.00106094, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00789614, Final residual = 6.27197e-05, No Iterations 4
# time step continuity errors : sum local = 1.71721e-09, global = -2.72091e-10, cumulative = 5.33063e-09
# ExecutionTime = 524.9 s  ClockTime = 525 s
#
# Time = 2.1e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00982165, Final residual = 0.000900405, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0.0114289, Final residual = 0.000966491, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.0117153, Final residual = 0.000969202, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00701642, Final residual = 6.49569e-05, No Iterations 3
# time step continuity errors : sum local = 1.78837e-09, global = 6.33633e-10, cumulative = 5.96426e-09
# ExecutionTime = 546.84 s  ClockTime = 547 s
#
# Time = 2.2e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0087693, Final residual = 0.000814834, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0.0103283, Final residual = 0.000885305, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.0105275, Final residual = 0.000885532, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00628781, Final residual = 5.0594e-05, No Iterations 4
# time step continuity errors : sum local = 1.39945e-09, global = -2.17839e-10, cumulative = 5.74642e-09
# ExecutionTime = 569.6 s  ClockTime = 570 s
#
# Time = 2.3e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00778362, Final residual = 0.000736547, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0.00942589, Final residual = 0.000809968, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00968379, Final residual = 0.000814313, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00563468, Final residual = 5.36533e-05, No Iterations 3
# time step continuity errors : sum local = 1.4901e-09, global = 5.05599e-10, cumulative = 6.25202e-09
# ExecutionTime = 591.51 s  ClockTime = 592 s
#
# Time = 2.4e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00700235, Final residual = 0.000669591, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0.00855267, Final residual = 0.000744833, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00873832, Final residual = 0.000747253, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00505932, Final residual = 4.1203e-05, No Iterations 4
# time step continuity errors : sum local = 1.14824e-09, global = -1.75601e-10, cumulative = 6.07642e-09
# ExecutionTime = 614.19 s  ClockTime = 614 s
#
# Time = 2.5e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00625218, Final residual = 0.000607944, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0.00783945, Final residual = 0.000684107, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00807234, Final residual = 0.000689829, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00454368, Final residual = 4.46729e-05, No Iterations 3
# time step continuity errors : sum local = 1.24868e-09, global = 4.05938e-10, cumulative = 6.48236e-09
# ExecutionTime = 636.3 s  ClockTime = 637 s
#
# Time = 2.6e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00565348, Final residual = 0.000554836, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0.00713967, Final residual = 0.000631221, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00731062, Final residual = 0.000635104, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00408124, Final residual = 3.38345e-05, No Iterations 4
# time step continuity errors : sum local = 9.48139e-10, global = -1.4255e-10, cumulative = 6.33981e-09
# ExecutionTime = 658.93 s  ClockTime = 659 s
#
# Time = 2.7e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00507159, Final residual = 0.000505717, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0.00656964, Final residual = 0.000581736, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00677868, Final residual = 0.000588175, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00366587, Final residual = 2.67853e-05, No Iterations 4
# time step continuity errors : sum local = 7.52287e-10, global = -1.21677e-10, cumulative = 6.21813e-09
# ExecutionTime = 681.71 s  ClockTime = 682 s
#
# Time = 2.8e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00458557, Final residual = 0.000373158, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00601045, Final residual = 0.000537957, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00619681, Final residual = 0.000544257, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00329519, Final residual = 2.35172e-05, No Iterations 4
# time step continuity errors : sum local = 6.61785e-10, global = -1.03845e-10, cumulative = 6.11429e-09
# ExecutionTime = 704.56 s  ClockTime = 705 s
#
# Time = 2.9e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00413389, Final residual = 0.000339402, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00558185, Final residual = 0.000502723, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00574241, Final residual = 0.00050783, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00295872, Final residual = 2.15213e-05, No Iterations 4
# time step continuity errors : sum local = 6.06655e-10, global = -9.44553e-11, cumulative = 6.01983e-09
# ExecutionTime = 727.52 s  ClockTime = 728 s
#
# Time = 3e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00373606, Final residual = 0.000310042, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.0051481, Final residual = 0.00046692, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00531013, Final residual = 0.000473044, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00265822, Final residual = 1.98914e-05, No Iterations 4
# time step continuity errors : sum local = 5.61554e-10, global = -8.78301e-11, cumulative = 5.932e-09
# ExecutionTime = 769.99 s  ClockTime = 770 s
#
# Time = 3.1e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00338503, Final residual = 0.000284019, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00474481, Final residual = 0.00043306, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00490329, Final residual = 0.000439821, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00238867, Final residual = 1.83246e-05, No Iterations 4
# time step continuity errors : sum local = 5.18003e-10, global = -8.11946e-11, cumulative = 5.85081e-09
# ExecutionTime = 793.04 s  ClockTime = 793 s
#
# Time = 3.2e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00307298, Final residual = 0.000260682, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00437601, Final residual = 0.000401792, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00452745, Final residual = 0.000408699, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00214656, Final residual = 1.68041e-05, No Iterations 4
# time step continuity errors : sum local = 4.75574e-10, global = -7.45084e-11, cumulative = 5.7763e-09
# ExecutionTime = 815.94 s  ClockTime = 816 s
#
# Time = 3.3e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00279416, Final residual = 0.000239612, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00404023, Final residual = 0.000373093, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00418371, Final residual = 0.000379944, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00192912, Final residual = 1.53812e-05, No Iterations 4
# time step continuity errors : sum local = 4.35746e-10, global = -6.81246e-11, cumulative = 5.70817e-09
# ExecutionTime = 838.71 s  ClockTime = 839 s
#
# Time = 3.4e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00254433, Final residual = 0.000220521, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00373462, Final residual = 0.00034677, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00387065, Final residual = 0.000353536, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00173389, Final residual = 1.40857e-05, No Iterations 4
# time step continuity errors : sum local = 3.99402e-10, global = -6.22509e-11, cumulative = 5.64592e-09
# ExecutionTime = 861.61 s  ClockTime = 862 s
#
# Time = 3.5e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00232006, Final residual = 0.000203186, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00345606, Final residual = 0.000322601, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.0035854, Final residual = 0.000329298, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00155864, Final residual = 1.29172e-05, No Iterations 4
# time step continuity errors : sum local = 3.66558e-10, global = -5.69261e-11, cumulative = 5.589e-09
# ExecutionTime = 884.4 s  ClockTime = 885 s
#
# Time = 3.6e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00211844, Final residual = 0.000187422, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00320164, Final residual = 0.000300376, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.0033249, Final residual = 0.000307012, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00140147, Final residual = 1.18613e-05, No Iterations 4
# time step continuity errors : sum local = 3.36828e-10, global = -5.21008e-11, cumulative = 5.5369e-09
# ExecutionTime = 907.14 s  ClockTime = 907 s
#
# Time = 3.7e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0019369, Final residual = 0.00017307, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00296888, Final residual = 0.000279911, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00308641, Final residual = 0.000286475, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00126103, Final residual = 1.09035e-05, No Iterations 4
# time step continuity errors : sum local = 3.0982e-10, global = -4.77158e-11, cumulative = 5.48918e-09
# ExecutionTime = 930.02 s  ClockTime = 930 s
#
# Time = 3.8e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00177323, Final residual = 0.000159985, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00275558, Final residual = 0.000261044, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00286763, Final residual = 0.000267515, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00113514, Final residual = 1.00323e-05, No Iterations 4
# time step continuity errors : sum local = 2.85222e-10, global = -4.37199e-11, cumulative = 5.44546e-09
# ExecutionTime = 952.85 s  ClockTime = 953 s
#
# Time = 3.9e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00162539, Final residual = 0.00014803, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00255984, Final residual = 0.000243623, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00266659, Final residual = 0.000249979, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.0010221, Final residual = 9.239e-06, No Iterations 4
# time step continuity errors : sum local = 2.62802e-10, global = -4.00762e-11, cumulative = 5.40538e-09
# ExecutionTime = 975.71 s  ClockTime = 976 s
#
# Time = 4e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0014916, Final residual = 0.000137087, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00238, Final residual = 0.000227519, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00248163, Final residual = 0.000233741, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.000920526, Final residual = 8.51714e-06, No Iterations 4
# time step continuity errors : sum local = 2.4238e-10, global = -3.67594e-11, cumulative = 5.36863e-09
# ExecutionTime = 1018.05 s  ClockTime = 1018 s
#
# Time = 4.1e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00137035, Final residual = 0.000127058, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00221454, Final residual = 0.000212617, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00231127, Final residual = 0.000218686, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00082922, Final residual = 7.86045e-06, No Iterations 4
# time step continuity errors : sum local = 2.23783e-10, global = -3.37444e-11, cumulative = 5.33488e-09
# ExecutionTime = 1040.97 s  ClockTime = 1041 s
#
# Time = 4.2e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00126029, Final residual = 0.000117855, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00206214, Final residual = 0.000198812, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00215416, Final residual = 0.000204716, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.000747128, Final residual = 7.26304e-06, No Iterations 4
# time step continuity errors : sum local = 2.0685e-10, global = -3.10076e-11, cumulative = 5.30387e-09
# ExecutionTime = 1063.76 s  ClockTime = 1064 s
#
# Time = 4.3e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00116027, Final residual = 0.0001094, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00192161, Final residual = 0.000186011, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.0020091, Final residual = 0.000191742, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.000673315, Final residual = 6.71937e-06, No Iterations 4
# time step continuity errors : sum local = 1.91427e-10, global = -2.85285e-11, cumulative = 5.27534e-09
# ExecutionTime = 1086.59 s  ClockTime = 1087 s
#
# Time = 4.4e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00106925, Final residual = 0.000101624, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.0017919, Final residual = 0.000174133, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00187505, Final residual = 0.000179682, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.000606966, Final residual = 4.11149e-06, No Iterations 5
# time step continuity errors : sum local = 1.17165e-10, global = 2.712e-11, cumulative = 5.30246e-09
# ExecutionTime = 1110.3 s  ClockTime = 1111 s
#
# Time = 4.5e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.000988589, Final residual = 9.44995e-05, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00167653, Final residual = 0.000163196, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00175976, Final residual = 0.000168746, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.000546602, Final residual = 5.27187e-06, No Iterations 4
# time step continuity errors : sum local = 1.50271e-10, global = -2.29358e-11, cumulative = 5.27953e-09
# ExecutionTime = 1133.22 s  ClockTime = 1134 s
#
# Time = 4.6e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.000909078, Final residual = 8.7857e-05, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00155849, Final residual = 0.000152791, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00163054, Final residual = 0.000157911, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00049368, Final residual = 3.45843e-06, No Iterations 5
# time step continuity errors : sum local = 9.86024e-11, global = 2.28542e-11, cumulative = 5.30238e-09
# ExecutionTime = 1156.74 s  ClockTime = 1157 s
#
# Time = 4.7e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.000843242, Final residual = 8.18055e-05, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00146137, Final residual = 0.000143365, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00153461, Final residual = 0.00014841, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.000445027, Final residual = 2.98385e-06, No Iterations 5
# time step continuity errors : sum local = 8.50888e-11, global = 1.97362e-11, cumulative = 5.32212e-09
# ExecutionTime = 1180.31 s  ClockTime = 1181 s
#
# Time = 4.8e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00077834, Final residual = 7.61611e-05, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00136383, Final residual = 0.000134446, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00143132, Final residual = 0.000139257, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.000402236, Final residual = 2.74695e-06, No Iterations 5
# time step continuity errors : sum local = 7.83476e-11, global = 1.82071e-11, cumulative = 5.34033e-09
# ExecutionTime = 1204.49 s  ClockTime = 1205 s
#
# Time = 4.9e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00072041, Final residual = 7.09683e-05, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00127515, Final residual = 0.000126167, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00133853, Final residual = 0.00013073, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.000363782, Final residual = 2.58747e-06, No Iterations 5
# time step continuity errors : sum local = 7.3811e-11, global = 1.71928e-11, cumulative = 5.35752e-09
# ExecutionTime = 1228.14 s  ClockTime = 1228 s
#
# Time = 5e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.000667409, Final residual = 6.61673e-05, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00119331, Final residual = 0.00011846, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00125315, Final residual = 0.000122796, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.000329141, Final residual = 2.45039e-06, No Iterations 5
# time step continuity errors : sum local = 6.99108e-11, global = 1.63378e-11, cumulative = 5.37386e-09
# ExecutionTime = 1271.26 s  ClockTime = 1272 s
#
# End
#
#
# >>> postProcess -func 'flowRatePatch(name=inlet)'
#
# /*---------------------------------------------------------------------------*\
# | =========                 |                                                 |
# | \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox           |
# |  \\    /   O peration     | Version:  2412                                  |
# |   \\  /    A nd           | Website:  www.openfoam.com                      |
# |    \\/     M anipulation  |                                                 |
# \*---------------------------------------------------------------------------*/
# Build  : _e5c6ccc3-20250814 OPENFOAM=2412 patch=250814 version=2412
# Arch   : "LSB;label=32;scalar=64"
# Exec   : postProcess -func flowRatePatch(name=inlet)
# Date   : Feb 04 2026
# Time   : 16:49:46
# Host   : e-10aux32876g5
# PID    : 293790
# I/O    : uncollated
# Case   : /home/h09435ap/porePermFoam/beadpack
# nProcs : 1
# trapFpe: Floating point exception trapping enabled (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 5, maxFileModificationPolls 20)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# --> FOAM Warning :
#     From static Foam::IOstreamOption::compressionType Foam::IOstreamOption::compressionEnum(const Foam::word&, Foam::IOstreamOption::compressionType)
#     in file db/options/IOstreamOption.C at line 189
#     Unknown compression specifier 'uncompressed' using compression off
# Create mesh for time = 0
#
# surfaceFieldValue flowRatePatch(name=inlet):
#     operation     = sum
#
#
# Time = 0
# --> FOAM Warning :
#     From virtual bool Foam::functionObjects::fieldSelection::checkSelection()
#     in file functionObjects/fieldSelections/fieldSelection/fieldSelection.C at line 179
#     Field phi not found
#
# Reading fields:
#
# Executing functionObjects
# surfaceFieldValue flowRatePatch(name=inlet) write:
#     total faces   = 27576
#     total area    = 1.09423e-07
#
# --> FOAM Warning :
#     From Foam::label Foam::functionObjects::fieldValues::surfaceFieldValue::writeAll(const vectorField&, const Foam::Field<Type>&, const pointField&, const faceList&) [with WeightType = double; Foam::label = int; Foam::vectorField = Foam::Field<Foam::Vector<double> >; Foam::pointField = Foam::Field<Foam::Vector<double> >; Foam::faceList = Foam::List<Foam::face>]
#     in file fieldValues/surfaceFieldValue/surfaceFieldValueTemplates.C at line 384
#     Requested field phi not found in database and not processed
#
#
# Time = 1e-05
#
# Reading fields:
#     surfaceScalarField: phi
#
# Executing functionObjects
# surfaceFieldValue flowRatePatch(name=inlet) write:
#     sum(inlet) of phi = -2.93022e-12
#
#
# Time = 2e-05
#
# Reading fields:
#     surfaceScalarField: phi
#
# Executing functionObjects
# surfaceFieldValue flowRatePatch(name=inlet) write:
#     sum(inlet) of phi = -3.88558e-12
#
#
# Time = 3e-05
#
# Reading fields:
#     surfaceScalarField: phi
#
# Executing functionObjects
# surfaceFieldValue flowRatePatch(name=inlet) write:
#     sum(inlet) of phi = -4.29162e-12
#
#
# Time = 4e-05
#
# Reading fields:
#     surfaceScalarField: phi
#
# Executing functionObjects
# surfaceFieldValue flowRatePatch(name=inlet) write:
#     sum(inlet) of phi = -4.47699e-12
#
#
# Time = 5e-05
#
# Reading fields:
#     surfaceScalarField: phi
#
# Executing functionObjects
# surfaceFieldValue flowRatePatch(name=inlet) write:
#     sum(inlet) of phi = -4.56258e-12
#
#
# End
#
#
# >>> postProcess -func 'flowRatePatch(name=outlet)'
#
# /*---------------------------------------------------------------------------*\
# | =========                 |                                                 |
# | \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox           |
# |  \\    /   O peration     | Version:  2412                                  |
# |   \\  /    A nd           | Website:  www.openfoam.com                      |
# |    \\/     M anipulation  |                                                 |
# \*---------------------------------------------------------------------------*/
# Build  : _e5c6ccc3-20250814 OPENFOAM=2412 patch=250814 version=2412
# Arch   : "LSB;label=32;scalar=64"
# Exec   : postProcess -func flowRatePatch(name=outlet)
# Date   : Feb 04 2026
# Time   : 16:50:56
# Host   : e-10aux32876g5
# PID    : 293935
# I/O    : uncollated
# Case   : /home/h09435ap/porePermFoam/beadpack
# nProcs : 1
# trapFpe: Floating point exception trapping enabled (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 5, maxFileModificationPolls 20)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# --> FOAM Warning :
#     From static Foam::IOstreamOption::compressionType Foam::IOstreamOption::compressionEnum(const Foam::word&, Foam::IOstreamOption::compressionType)
#     in file db/options/IOstreamOption.C at line 189
#     Unknown compression specifier 'uncompressed' using compression off
# Create mesh for time = 0
#
# surfaceFieldValue flowRatePatch(name=outlet):
#     operation     = sum
#
#
# Time = 0
# --> FOAM Warning :
#     From virtual bool Foam::functionObjects::fieldSelection::checkSelection()
#     in file functionObjects/fieldSelections/fieldSelection/fieldSelection.C at line 179
#     Field phi not found
#
# Reading fields:
#
# Executing functionObjects
# surfaceFieldValue flowRatePatch(name=outlet) write:
#     total faces   = 26544
#     total area    = 1.05328e-07
#
# --> FOAM Warning :
#     From Foam::label Foam::functionObjects::fieldValues::surfaceFieldValue::writeAll(const vectorField&, const Foam::Field<Type>&, const pointField&, const faceList&) [with WeightType = double; Foam::label = int; Foam::vectorField = Foam::Field<Foam::Vector<double> >; Foam::pointField = Foam::Field<Foam::Vector<double> >; Foam::faceList = Foam::List<Foam::face>]
#     in file fieldValues/surfaceFieldValue/surfaceFieldValueTemplates.C at line 384
#     Requested field phi not found in database and not processed
#
#
# Time = 1e-05
#
# Reading fields:
#     surfaceScalarField: phi
#
# Executing functionObjects
# surfaceFieldValue flowRatePatch(name=outlet) write:
#     sum(outlet) of phi = 2.8871e-12
#
#
# Time = 2e-05
#
# Reading fields:
#     surfaceScalarField: phi
#
# Executing functionObjects
# surfaceFieldValue flowRatePatch(name=outlet) write:
#     sum(outlet) of phi = 3.87165e-12
#
#
# Time = 3e-05
#
# Reading fields:
#     surfaceScalarField: phi
#
# Executing functionObjects
# surfaceFieldValue flowRatePatch(name=outlet) write:
#     sum(outlet) of phi = 4.28712e-12
#
#
# Time = 4e-05
#
# Reading fields:
#     surfaceScalarField: phi
#
# Executing functionObjects
# surfaceFieldValue flowRatePatch(name=outlet) write:
#     sum(outlet) of phi = 4.47511e-12
#
#
# Time = 5e-05
#
# Reading fields:
#     surfaceScalarField: phi
#
# Executing functionObjects
# surfaceFieldValue flowRatePatch(name=outlet) write:
#     sum(outlet) of phi = 4.56342e-12
#
#
# End
#
# Warning: 6 times vs 5 rates for 'inlet'
# Warning: 6 times vs 5 rates for 'outlet'
# Wrote 5 records with area=1.09423e-07 to beadpack/q_in.csv
# Wrote 5 records with area=1.05328e-07 to beadpack/q_out.csv
#
# --- inlet fluxes ---
# t=0         , q_in=-2.93022e-12, A_in=1.09423e-07
# t=1e-05     , q_in=-3.88558e-12, A_in=1.09423e-07
# t=2e-05     , q_in=-4.29162e-12, A_in=1.09423e-07
# t=3e-05     , q_in=-4.47699e-12, A_in=1.09423e-07
# t=4e-05     , q_in=-4.56258e-12, A_in=1.09423e-07
#
# --- outlet fluxes ---
# t=0         , q_out=2.88710e-12, A_out=1.05328e-07
# t=1e-05     , q_out=3.87165e-12, A_out=1.05328e-07
# t=2e-05     , q_out=4.28712e-12, A_out=1.05328e-07
# t=3e-05     , q_out=4.47511e-12, A_out=1.05328e-07
# t=4e-05     , q_out=4.56342e-12, A_out=1.05328e-07

# %%
df_q_area = pd.read_csv(f"{sample}/q_in.csv")
df_q_area.head()
# Out:
#       time  flowRate_phi          area
# 0  0.00000 -2.930220e-12  1.094230e-07
# 1  0.00001 -3.885580e-12  1.094230e-07
# 2  0.00002 -4.291620e-12  1.094230e-07
# 3  0.00003 -4.476990e-12  1.094230e-07
# 4  0.00004 -4.562580e-12  1.094230e-07

# %%
phi = sft.vti_phi(vti_path)
print(f"Porosity: {phi:.02%}")

# Cross-sectional area
A = shape[1] * shape[2] * scale**2
miu = 1e-3  # fluid viscosity [Pa·s]
L = shape[0] * scale  # length [m]

# Flow rate from last timestep
Q = np.abs(df_q_area["flowRate_phi"].iloc[-1])

# Darcy's law
k = Q * miu * L / (A * dp)

print(f"Permeability: {k:.02e} m^2")
print(f"Permeability: {k * 1.01324997e15:.02f} md")
# Out:
# Porosity: 35.94%
# Permeability: 9.13e-12 m^2
# Permeability: 9246.07 md
