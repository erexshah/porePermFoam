# %% [markdown]
# # 📄 Permeability Estimation from VTI Pore Geometry using `porePermFoam`
#
# This notebook demonstrates the **end-to-end workflow** for running a pore-scale CFD simulation in OpenFOAM using the `porePermFoam` (via `simpleFoam_tools`) package.
#
# We will:
# 1. Load a binary `.vti` pore geometry.
# 2. Automatically generate OpenFOAM case files.
# 3. Run a `simpleFoam` simulation.
# 4. Post-process results to compute **porosity** and **permeability**.
#
# ---
#
# ## 1️⃣ Import Required Packages
# We import:
# - `simpleFoam_tools` (`sft`) for case generation, meshing, simulation, and post-processing.
# - `pandas` and `numpy` for handling and analyzing results.

# %%
import simpleFoam_tools as sft
import pandas as pd
import numpy as np

# %% [markdown]
# ## 2️⃣ Remove Any Previous Case Files (Optional)
#
# To start fresh, we remove any previously generated OpenFOAM case directories and results using:
# `sft.remove_run_files(".")`.
#
# This ensures no old mesh or simulation results interfere with the new run.

# %%
remove = 1
if remove:
    sft.remove_run_files(".")

# %% [markdown]
# ## 3️⃣ Define Simulation Parameters
#
# The key inputs are:
#
# - **domain_name**: base name of the `.vti` file in `constant/geometry/`. **(Note: place your vti file in `constant/geometry/` directory)**
# - **scale**: physical size of each voxel (meters).
# - **dp**: differential pressure (Pa).
# - **refinement**: local mesh refinement level (0 = none).
# - **factor_mesh**: global mesh resolution scaling.
# - **boundary_type**: `"symmetryPlane"` or `"Wall"`.
# - **dt**: simulation time step (s).
# - **end_time**: simulation duration (s).
# - **write_interval**: how often to write simulation results (timesteps).

# %%
domain_name = "vti_bent_x"  # "cylinder" or "vti_bent_x"

scale = 3.0035e-6  # voxel size [m]
dp = 1.0           # pressure difference [Pa]
refinement = 0     # local refinement level
factor_mesh = 1    # global mesh scale factor

boundary_type = "symmetryPlane"  # "symmetryPlane" or "Wall"

dt = 1e-6
end_time = 500e-6
write_interval = 100

# %% [markdown]
# ## 4️⃣ Generate OpenFOAM Case Files from `.vti` Geometry
#
# Here we:
# 1. Get the voxel shape of the domain.
# 2. Convert `.vti` → `.stl` surface mesh.
# 3. Generate:
#    - `blockMeshDict`
#    - `snappyHexMeshDict`
#    - `controlDict`
#    - Initial pressure and velocity fields.

# %%
# Get voxel shape and a pore voxel location from VTI
vti_path = f"constant/geometry/{domain_name}.vti"
shape = sft.vti_shape(vti_path)
location_in_mesh = sft.find_pore_location(vti_path)

# Convert VTI to STL surface mesh
stl = f"{domain_name}.stl"
stl_path = f"constant/triSurface/{stl}"
sft.vti_to_stl(vti_path, stl_path)

# Adjust mesh resolution
mesh_resolution = tuple(x * factor_mesh for x in shape)

# File paths
blockMeshDict_path    = "system/blockMeshDict"
controlDict_path      = "system/controlDict"
p_field_path          = "0/p"
U_field_path          = "0/U"
snappyHexMeshDict_path = "system/snappyHexMeshDict"

# Generate OpenFOAM files
sft.generate_blockMeshDict(shape, mesh_resolution, blockMeshDict_path, boundary=boundary_type)
sft.generate_snappyHexMeshDict(location_in_mesh, stl, snappyHexMeshDict_path, refinement=refinement)
sft.generate_controlDict(controlDict_path, end_time=end_time, write_interval=write_interval, dt=dt)
sft.generate_pressure_field(p_field_path, dp=dp, boundary=boundary_type)
sft.generate_velocity_field(U_field_path, boundary=boundary_type)
# Out:
# Running command: pvpython /home/h09435ap/porePermFoam/simpleFoam_tools/paraview_stl.py /home/h09435ap/porePermFoam/constant/geometry/vti_bent_x.vti /home/h09435ap/porePermFoam/constant/triSurface/vti_bent_x.stl
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# ✅ Wrote ASCII STL: /home/h09435ap/porePermFoam/constant/triSurface/vti_bent_x.stl
# Generated blockMeshDict at: system/blockMeshDict
# Generated snappyHexMeshDict at: system/snappyHexMeshDict
# Generated controlDict at: system/controlDict
# Generated p at: 0/p with boundary symmetryPlane
# Generated U at: 0/U with boundary symmetryPlane

# %% [markdown]
# ## 5️⃣ Run the Simulation
#
# We now run the `simpleFoam` steady-state solver directly from Python using `sft.run_simplefoam`.
#
# This step will:
# - Run meshing (`blockMesh` + `snappyHexMesh`)
# - Solve flow equations.
# - Output results in CSV for post-processing.

# %%
sft.run_simplefoam(".", scale=scale)
# Out:
# >>> blockMesh
#
# /*---------------------------------------------------------------------------*\
# | =========                 |                                                 |
# | \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox           |
# |  \\    /   O peration     | Version:  2412                                  |
# |   \\  /    A nd           | Website:  www.openfoam.com                      |
# |    \\/     M anipulation  |                                                 |
# \*---------------------------------------------------------------------------*/
# Build  : _f00230df-20250528 OPENFOAM=2412 patch=250528 version=2412
# Arch   : "LSB;label=32;scalar=64"
# Exec   : blockMesh
# Date   : Aug 08 2025
# Time   : 13:38:31
# Host   : e-10aux32876g5
# PID    : 2181884
# I/O    : uncollated
# Case   : /home/h09435ap/porePermFoam
# nProcs : 1
# trapFpe: Floating point exception trapping enabled (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 5, maxFileModificationPolls 20)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# --> FOAM Warning :
#     From static Foam::IOstreamOption::compressionType Foam::IOstreamOption::compressionEnum(const Foam::word&, Foam::IOstreamOption::compressionType)
#     in file db/options/IOstreamOption.C at line 189
#     Unknown compression specifier 'uncompressed' using compression off
# Creating block mesh from "system/blockMeshDict"
# --> FOAM IOWarning :
#     Found [v1012] 'convertToMeters' entry instead of 'scale' in dictionary "system/blockMeshDict"
#
#     This keyword is 168 months old.
#
# Creating block edges
# No non-planar block faces defined
# Creating topology blocks
#
# Creating topology patches - from boundary section
#
# Creating block mesh topology
#
# Check topology
#
# 	Basic statistics
# 		Number of internal faces : 0
# 		Number of boundary faces : 6
# 		Number of defined boundary faces : 6
# 		Number of undefined boundary faces : 0
# 	Checking patch -> block consistency
#
# Creating block offsets
# Creating merge list (topological search)...
#
# Creating polyMesh from blockMesh
# Creating patches
# Creating cells
# Creating points with scale (1 1 1)
#     Block 0 cell size :
#         i : 0.99 .. 0.99
#         j : 0.99 .. 0.99
#         k : 0.99 .. 0.99
#
# No patch pairs to merge
#
# Writing polyMesh with 0 cellZones
# ----------------
# Mesh Information
# ----------------
#   boundingBox: (0 0 0) (99 99 99)
#   nPoints: 1030301
#   nCells: 1000000
#   nFaces: 3030000
#   nInternalFaces: 2970000
# ----------------
# Patches
# ----------------
#   patch 0 (start: 2970000 size: 10000) name: top
#   patch 1 (start: 2980000 size: 10000) name: inlet
#   patch 2 (start: 2990000 size: 10000) name: bottom
#   patch 3 (start: 3000000 size: 10000) name: outlet
#   patch 4 (start: 3010000 size: 10000) name: front
#   patch 5 (start: 3020000 size: 10000) name: back
#
# End
#
#
# >>> snappyHexMesh -overwrite
#
# /*---------------------------------------------------------------------------*\
# | =========                 |                                                 |
# | \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox           |
# |  \\    /   O peration     | Version:  2412                                  |
# |   \\  /    A nd           | Website:  www.openfoam.com                      |
# |    \\/     M anipulation  |                                                 |
# \*---------------------------------------------------------------------------*/
# Build  : _f00230df-20250528 OPENFOAM=2412 patch=250528 version=2412
# Arch   : "LSB;label=32;scalar=64"
# Exec   : snappyHexMesh -overwrite
# Date   : Aug 08 2025
# Time   : 13:38:34
# Host   : e-10aux32876g5
# PID    : 2181897
# I/O    : uncollated
# Case   : /home/h09435ap/porePermFoam
# nProcs : 1
# trapFpe: Floating point exception trapping enabled (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 5, maxFileModificationPolls 20)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# --> FOAM Warning :
#     From static Foam::IOstreamOption::compressionType Foam::IOstreamOption::compressionEnum(const Foam::word&, Foam::IOstreamOption::compressionType)
#     in file db/options/IOstreamOption.C at line 189
#     Unknown compression specifier 'uncompressed' using compression off
# Create mesh for time = 0
#
# Read mesh in = 1.98 s
#
# Overall mesh bounding box  : (0 0 0) (99 99 99)
# Relative tolerance         : 1e-06
# Absolute matching distance : 0.000171473
#
# Reading refinement surfaces.
# Read refinement surfaces in = 0.09 s
#
# Reading refinement shells.
# Read refinement shells in = 0 s
#
# Setting refinement level of surface to be consistent with shells.
# For geometry vti_bent_x.stl detected 0 uncached triangles out of 220520
# Checked shell refinement in = 0.28 s
#
# Reading features.
# Read features in = 0 s
#
#
# Determining initial surface intersections
# -----------------------------------------
#
# Edge intersection testing:
#     Number of edges             : 3030000
#     Number of edges to retest   : 0
#     Number of intersected edges : 0
# Edge intersection testing:
#     Number of edges             : 3030000
#     Number of edges to retest   : 3030000
#     Number of intersected edges : 112616
# Calculated surface intersections in = 1.75 s
#
# Initial mesh : cells:1000000  faces:3030000  points:1030301
# Cells per refinement level:
#     0	1000000
# Setting refinement level of surface to be consistent with curvature.
# Checked curvature refinement in = 0 s
#
#
# Adding patches for surface regions
# ----------------------------------
#
# Patch Type                Region
# ----- ----                ------
# solids:
#
# 6     wall                solids
#
# Added patches in = 0.03 s
#
# Edge intersection testing:
#     Number of edges             : 3030000
#     Number of edges to retest   : 0
#     Number of intersected edges : 112616
# Decomposition method none [1]
#
# Refinement phase
# ----------------
#
# Found point (51 50 50) in cell 505051 on processor 0
#
# Surface refinement iteration 0
# ------------------------------
#
# Marked for refinement due to surface intersection          : 0 cells.
# Determined cells to refine in = 0.51 s
# Selected for refinement : 0 cells (out of 1000000)
# Stopping refining since too few cells selected.
#
#
# Removing mesh beyond surface intersections
# ------------------------------------------
#
# Setting cellZones according to locationsInMesh:
# Location : (51 50 50)
#     cellZone : none
#
# For cellZone none found point (51 50 50) in global region 1 out of 15 regions.
# --> FOAM Warning :
#     From void Foam::meshRefinement::nearestFace(const labelUList&, const Foam::bitSet&, Foam::autoPtr<Foam::mapDistribute>&, Foam::labelList&, Foam::label) const
#     in file meshRefinement/meshRefinement.C at line 527
#     Did not visit some faces, e.g. face 168 at (56.43 0.495 0.495)
# Keeping all cells containing inside points
# Selected for keeping : 392673 cells.
# Edge intersection testing:
#     Number of edges             : 1259487
#     Number of edges to retest   : 102999
#     Number of intersected edges : 112616
#
# Shell refinement iteration 0
# ----------------------------
#
# Marked for refinement due to distance to explicit features : 0 cells.
# Marked for refinement due to refinement shells             : 0 cells.
# Determined cells to refine in = 1.13 s
# Selected for internal refinement : 0 cells (out of 392673)
# Stopping refining since too few cells selected.
#
#
# Dangling coarse cells refinement iteration 0
# --------------------------------------------
#
# Determined cells to refine in = 0.01 s
# Selected for refinement : 0 cells (out of 392673)
# Stopping refining since too few cells selected.
#
#
# Dangling coarse cells refinement iteration 0
# --------------------------------------------
#
# Determined cells to refine in = 0.01 s
# Selected for refinement : 0 cells (out of 392673)
# Stopping refining since too few cells selected.
#
#
# Refinement transition refinement iteration 0
# --------------------------------------------
#
# Determined cells to refine in = 0 s
# Selected for refinement : 0 cells (out of 392673)
# Stopping refining since too few cells selected.
#
#
# Splitting mesh at surface intersections
# ---------------------------------------
#
# Introducing baffles for 112616 faces that are intersected by the surface.
#
# Setting cellZones according to locationsInMesh:
# Location : (51 50 50)
#     cellZone : none
#
# For cellZone none found point (51 50 50) in global region 1 out of 75 regions.
# Edge intersection testing:
#     Number of edges             : 1329205
#     Number of edges to retest   : 533833
#     Number of intersected edges : 182334
# Created baffles in = 0.71 s
#
#
# After introducing baffles : cells:392673  faces:1329205  points:473845
# Cells per refinement level:
#     0	392673
#
# Introducing baffles to block off problem cells
# ----------------------------------------------
#
# markFacesOnProblemCells : marked 212913 additional internal faces to be converted into baffles.
# Analyzed problem cells in = 0.29 s
#
#
# Introducing baffles to delete problem cells.
#
# Edge intersection testing:
#     Number of edges             : 1542118
#     Number of edges to retest   : 646926
#     Number of intersected edges : 182334
# Created baffles in = 0.62 s
#
#
# After introducing baffles : cells:392673  faces:1542118  points:473845
# Cells per refinement level:
#     0	392673
# Setting cellZones according to locationsInMesh:
# Location : (51 50 50)
#     cellZone : none
#
# For cellZone none found point (51 50 50) in global region 6 out of 106182 regions.
# Edge intersection testing:
#     Number of edges             : 1542118
#     Number of edges to retest   : 661264
#     Number of intersected edges : 182334
#
# Remove unreachable sections of mesh
# -----------------------------------
#
# Keeping all cells containing points 1((51 50 50))
# Selected for keeping : 283480 cells.
# Edge intersection testing:
#     Number of edges             : 892914
#     Number of edges to retest   : 0
#     Number of intersected edges : 67746
# Split mesh in = 1.22 s
#
#
# After subsetting : cells:283480  faces:892914  points:326921
# Cells per refinement level:
#     0	283480
#
# Introducing zones for interfaces
# --------------------------------
#
# Setting cellZones according to locationsInMesh:
# Location : (51 50 50)
#     cellZone : none
#
# For cellZone none found point (51 50 50) in global region 0 out of 1 regions.
# Setting faceZones according to neighbouring cellZones:
#
# Edge intersection testing:
#     Number of edges             : 892914
#     Number of edges to retest   : 0
#     Number of intersected edges : 67746
#
# Handling cells with snap problems
# ---------------------------------
#
# Introducing baffles for 67746 faces that are intersected by the surface.
#
# Setting cellZones according to locationsInMesh:
# Location : (51 50 50)
#     cellZone : none
#
# For cellZone none found point (51 50 50) in global region 0 out of 1 regions.
# Edge intersection testing:
#     Number of edges             : 892914
#     Number of edges to retest   : 181327
#     Number of intersected edges : 67746
# Created baffles in = 0.66 s
#
#
# After introducing baffles : cells:283480  faces:892914  points:326921
# Cells per refinement level:
#     0	283480
#
# Introducing baffles to block off problem cells
# ----------------------------------------------
#
# markFacesOnProblemCells : marked 39 additional internal faces to be converted into baffles.
# Analyzed problem cells in = 0.18 s
#
#
# Introducing baffles to delete problem cells.
#
# Edge intersection testing:
#     Number of edges             : 892953
#     Number of edges to retest   : 193
#     Number of intersected edges : 67746
# Created baffles in = 0.2 s
#
#
# After introducing baffles : cells:283480  faces:892953  points:326921
# Cells per refinement level:
#     0	283480
# Setting cellZones according to locationsInMesh:
# Location : (51 50 50)
#     cellZone : none
#
# For cellZone none found point (51 50 50) in global region 0 out of 20 regions.
# Edge intersection testing:
#     Number of edges             : 892953
#     Number of edges to retest   : 181357
#     Number of intersected edges : 67746
#
# Remove unreachable sections of mesh
# -----------------------------------
#
# Keeping all cells containing points 1((51 50 50))
# Selected for keeping : 283461 cells.
# Edge intersection testing:
#     Number of edges             : 892839
#     Number of edges to retest   : 0
#     Number of intersected edges : 67704
# Split mesh in = 0.62 s
#
#
# After subsetting : cells:283461  faces:892839  points:326884
# Cells per refinement level:
#     0	283461
#
# Merge free-standing baffles
# ---------------------------
#
# freeStandingBaffles : detected 0 free-standing baffles out of 0
#
# Detected free-standing baffles : 0
# Merged free-standing baffles in = 0.06 s
#
#
# dupNonManifoldPoints : Found : 33 non-manifold points (out of 326884)
# Edge intersection testing:
#     Number of edges             : 892839
#     Number of edges to retest   : 0
#     Number of intersected edges : 67704
# Detected unsplittable baffles : 0
#
# Merge refined boundary faces
# ----------------------------
#
# Merging 0 sets of faces.
#
# No faces merged ...
#
# Merging all points on surface that
# - are used by only two boundary faces and
# - make an angle with a cosine of more than 0.707107.
#
# No straight edges simplified and no points removed ...
# Refined mesh : cells:283461  faces:892839  points:326917
# Cells per refinement level:
#     0	283461
# Writing mesh to time constant
# Wrote mesh in = 0.45 s.
# Mesh refined in = 6.96 s.
# Checking final mesh ...
# Checking faces in error :
#     non-orthogonality > 50  degrees                        : 0
#     faces with face pyramid volume < 1e-17                 : 0
#     faces with face-decomposition tet quality < 0.001      : 0
#     faces with concavity > 80  degrees                     : 0
#     faces with area < 1e-14 m^2                            : 0
#     faces with skewness > 4   (internal) or 20  (boundary) : 0
#     faces with interpolation weights (0..1)  < 0.02        : 0
#     faces with volume ratio of neighbour cells < 0.01      : 0
#     faces with face twist < 0.02                           : 0
#     faces with triangle twist < 0.02                       : 0
#     faces on cells with determinant < 0.001                : 0
# Finished meshing without any errors
# Finished meshing in = 11.59 s.
# End
#
#
# >>> transformPoints -scale "(3.0035e-06 3.0035e-06 3.0035e-06)"
#
# /*---------------------------------------------------------------------------*\
# | =========                 |                                                 |
# | \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox           |
# |  \\    /   O peration     | Version:  2412                                  |
# |   \\  /    A nd           | Website:  www.openfoam.com                      |
# |    \\/     M anipulation  |                                                 |
# \*---------------------------------------------------------------------------*/
# Build  : _f00230df-20250528 OPENFOAM=2412 patch=250528 version=2412
# Arch   : "LSB;label=32;scalar=64"
# Exec   : transformPoints -scale (3.0035e-06 3.0035e-06 3.0035e-06)
# Date   : Aug 08 2025
# Time   : 13:38:46
# Host   : e-10aux32876g5
# PID    : 2181927
# I/O    : uncollated
# Case   : /home/h09435ap/porePermFoam
# nProcs : 1
# trapFpe: Floating point exception trapping enabled (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 5, maxFileModificationPolls 20)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# --> FOAM Warning :
#     From static Foam::IOstreamOption::compressionType Foam::IOstreamOption::compressionEnum(const Foam::word&, Foam::IOstreamOption::compressionType)
#     in file db/options/IOstreamOption.C at line 189
#     Unknown compression specifier 'uncompressed' using compression off
# Scaling points uniformly by 3.0035e-06
# Writing points into directory "constant/polyMesh"
#
#
# End
#
#
# >>> simpleFoam
#
# /*---------------------------------------------------------------------------*\
# | =========                 |                                                 |
# | \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox           |
# |  \\    /   O peration     | Version:  2412                                  |
# |   \\  /    A nd           | Website:  www.openfoam.com                      |
# |    \\/     M anipulation  |                                                 |
# \*---------------------------------------------------------------------------*/
# Build  : _f00230df-20250528 OPENFOAM=2412 patch=250528 version=2412
# Arch   : "LSB;label=32;scalar=64"
# Exec   : simpleFoam
# Date   : Aug 08 2025
# Time   : 13:38:46
# Host   : e-10aux32876g5
# PID    : 2181929
# I/O    : uncollated
# Case   : /home/h09435ap/porePermFoam
# nProcs : 1
# trapFpe: Floating point exception trapping enabled (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 5, maxFileModificationPolls 20)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# --> FOAM Warning :
#     From static Foam::IOstreamOption::compressionType Foam::IOstreamOption::compressionEnum(const Foam::word&, Foam::IOstreamOption::compressionType)
#     in file db/options/IOstreamOption.C at line 189
#     Unknown compression specifier 'uncompressed' using compression off
# Create mesh for time = 0
#
#
# SIMPLE: no convergence criteria found. Calculations will run for 0.0005 steps.
#
# Reading field p
#
# Reading field U
#
# Reading/calculating face flux field phi
#
# Selecting incompressible transport model Newtonian
# Selecting turbulence model type laminar
# Selecting laminar stress model Stokes
# No MRF models present
#
# No finite volume options present
#
# Starting time loop
#
# Time = 1e-06
#
# smoothSolver:  Solving for Ux, Initial residual = 1, Final residual = 0.0815372, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0, Final residual = 0, No Iterations 0
# smoothSolver:  Solving for Uz, Initial residual = 0, Final residual = 0, No Iterations 0
# GAMG:  Solving for p, Initial residual = 1, Final residual = 0.0062055, No Iterations 6
# time step continuity errors : sum local = 3.51924e-08, global = -6.47474e-09, cumulative = -6.47474e-09
# ExecutionTime = 1.11 s  ClockTime = 1 s
#
# Time = 2e-06
#
# smoothSolver:  Solving for Ux, Initial residual = 0.473625, Final residual = 0.0365149, No Iterations 6
# smoothSolver:  Solving for Uy, Initial residual = 0.447978, Final residual = 0.0409429, No Iterations 6
# smoothSolver:  Solving for Uz, Initial residual = 0.452726, Final residual = 0.0416016, No Iterations 6
# GAMG:  Solving for p, Initial residual = 0.136653, Final residual = 0.0011204, No Iterations 4
# time step continuity errors : sum local = 3.05238e-08, global = 5.67544e-09, cumulative = -7.99291e-10
# ExecutionTime = 1.39 s  ClockTime = 1 s
#
# Time = 3e-06
#
# smoothSolver:  Solving for Ux, Initial residual = 0.306206, Final residual = 0.0281504, No Iterations 6
# smoothSolver:  Solving for Uy, Initial residual = 0.240977, Final residual = 0.0219848, No Iterations 8
# smoothSolver:  Solving for Uz, Initial residual = 0.256891, Final residual = 0.0235142, No Iterations 8
# GAMG:  Solving for p, Initial residual = 0.0867524, Final residual = 0.000451374, No Iterations 4
# time step continuity errors : sum local = 1.42227e-08, global = -1.1641e-09, cumulative = -1.96339e-09
# ExecutionTime = 1.69 s  ClockTime = 2 s
#
# Time = 4e-06
#
# smoothSolver:  Solving for Ux, Initial residual = 0.213566, Final residual = 0.0171397, No Iterations 7
# smoothSolver:  Solving for Uy, Initial residual = 0.152568, Final residual = 0.013228, No Iterations 9
# smoothSolver:  Solving for Uz, Initial residual = 0.165502, Final residual = 0.0148258, No Iterations 9
# GAMG:  Solving for p, Initial residual = 0.073466, Final residual = 0.000474174, No Iterations 4
# time step continuity errors : sum local = 1.4335e-08, global = -2.40256e-09, cumulative = -4.36595e-09
# ExecutionTime = 2.01 s  ClockTime = 2 s
#
# Time = 5e-06
#
# smoothSolver:  Solving for Ux, Initial residual = 0.153687, Final residual = 0.0135302, No Iterations 7
# smoothSolver:  Solving for Uy, Initial residual = 0.109708, Final residual = 0.0103718, No Iterations 9
# smoothSolver:  Solving for Uz, Initial residual = 0.11798, Final residual = 0.0116902, No Iterations 9
# GAMG:  Solving for p, Initial residual = 0.0658172, Final residual = 0.000410164, No Iterations 5
# time step continuity errors : sum local = 1.13257e-08, global = 3.83009e-09, cumulative = -5.35858e-10
# ExecutionTime = 2.35 s  ClockTime = 2 s
#
# Time = 6e-06
#
# smoothSolver:  Solving for Ux, Initial residual = 0.115133, Final residual = 0.0110189, No Iterations 7
# smoothSolver:  Solving for Uy, Initial residual = 0.0877125, Final residual = 0.00836089, No Iterations 9
# smoothSolver:  Solving for Uz, Initial residual = 0.0943089, Final residual = 0.00928032, No Iterations 9
# GAMG:  Solving for p, Initial residual = 0.0595891, Final residual = 0.000374755, No Iterations 5
# time step continuity errors : sum local = 1.00327e-08, global = 3.3732e-09, cumulative = 2.83734e-09
# ExecutionTime = 2.68 s  ClockTime = 3 s
#
# Time = 7e-06
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0888463, Final residual = 0.00726593, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0723869, Final residual = 0.00691993, No Iterations 9
# smoothSolver:  Solving for Uz, Initial residual = 0.0779255, Final residual = 0.00763331, No Iterations 9
# GAMG:  Solving for p, Initial residual = 0.0503298, Final residual = 0.000431407, No Iterations 4
# time step continuity errors : sum local = 1.22418e-08, global = -2.47329e-09, cumulative = 3.64052e-10
# ExecutionTime = 3 s  ClockTime = 3 s
#
# Time = 8e-06
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0707097, Final residual = 0.0060036, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0610777, Final residual = 0.00592356, No Iterations 9
# smoothSolver:  Solving for Uz, Initial residual = 0.0658034, Final residual = 0.00530552, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.0423398, Final residual = 0.000341505, No Iterations 4
# time step continuity errors : sum local = 1.02216e-08, global = -1.9485e-09, cumulative = -1.58444e-09
# ExecutionTime = 3.3 s  ClockTime = 3 s
#
# Time = 9e-06
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0579789, Final residual = 0.00511674, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0517822, Final residual = 0.00510776, No Iterations 9
# smoothSolver:  Solving for Uz, Initial residual = 0.0556681, Final residual = 0.00458942, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.0359317, Final residual = 0.000267846, No Iterations 4
# time step continuity errors : sum local = 8.35374e-09, global = -1.58322e-09, cumulative = -3.16766e-09
# ExecutionTime = 3.62 s  ClockTime = 4 s
#
# Time = 1e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0484603, Final residual = 0.00442948, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0444056, Final residual = 0.00357036, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.0477342, Final residual = 0.00402329, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.0309393, Final residual = 0.000294294, No Iterations 3
# time step continuity errors : sum local = 9.48503e-09, global = 4.77566e-09, cumulative = 1.608e-09
# ExecutionTime = 3.92 s  ClockTime = 4 s
#
# Time = 1.1e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0412227, Final residual = 0.00389381, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0384231, Final residual = 0.00312218, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.0417093, Final residual = 0.00359108, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.0270233, Final residual = 0.000217287, No Iterations 4
# time step continuity errors : sum local = 7.18697e-09, global = -1.2766e-09, cumulative = 3.31403e-10
# ExecutionTime = 4.23 s  ClockTime = 4 s
#
# Time = 1.2e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0352579, Final residual = 0.00345008, No Iterations 8
# smoothSolver:  Solving for Uy, Initial residual = 0.0335205, Final residual = 0.00272759, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.0369442, Final residual = 0.0032104, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.0235502, Final residual = 0.000220881, No Iterations 3
# time step continuity errors : sum local = 7.47122e-09, global = 3.51222e-09, cumulative = 3.84362e-09
# ExecutionTime = 4.53 s  ClockTime = 4 s
#
# Time = 1.3e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0306189, Final residual = 0.00246507, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0.0297283, Final residual = 0.00245103, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.0327916, Final residual = 0.00290005, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.0206358, Final residual = 0.000146915, No Iterations 4
# time step continuity errors : sum local = 5.06269e-09, global = -8.84083e-10, cumulative = 2.95954e-09
# ExecutionTime = 4.85 s  ClockTime = 5 s
#
# Time = 1.4e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0265465, Final residual = 0.00219455, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0.0267112, Final residual = 0.00221264, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.029675, Final residual = 0.00264318, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.0180163, Final residual = 0.00015259, No Iterations 3
# time step continuity errors : sum local = 5.35328e-09, global = 2.60754e-09, cumulative = 5.56708e-09
# ExecutionTime = 5.15 s  ClockTime = 5 s
#
# Time = 1.5e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0233737, Final residual = 0.00196808, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0.0240772, Final residual = 0.0020158, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.0267816, Final residual = 0.00242275, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.0158408, Final residual = 0.000110806, No Iterations 4
# time step continuity errors : sum local = 3.94723e-09, global = -6.60377e-10, cumulative = 4.90671e-09
# ExecutionTime = 5.47 s  ClockTime = 5 s
#
# Time = 1.6e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.020657, Final residual = 0.00178725, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0.021667, Final residual = 0.00181934, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.0243276, Final residual = 0.00221525, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.0138933, Final residual = 0.000124396, No Iterations 3
# time step continuity errors : sum local = 4.49203e-09, global = 1.97899e-09, cumulative = 6.8857e-09
# ExecutionTime = 5.77 s  ClockTime = 6 s
#
# Time = 1.7e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0184602, Final residual = 0.00162521, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0.0196867, Final residual = 0.00166728, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.0221078, Final residual = 0.0020391, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.0122514, Final residual = 9.14657e-05, No Iterations 4
# time step continuity errors : sum local = 3.3396e-09, global = -5.11823e-10, cumulative = 6.37387e-09
# ExecutionTime = 6.08 s  ClockTime = 6 s
#
# Time = 1.8e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0165304, Final residual = 0.00149061, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0.0178783, Final residual = 0.00151844, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.0201965, Final residual = 0.00187232, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.0107901, Final residual = 0.000103901, No Iterations 3
# time step continuity errors : sum local = 3.83086e-09, global = 1.55977e-09, cumulative = 7.93364e-09
# ExecutionTime = 6.4 s  ClockTime = 6 s
#
# Time = 1.9e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0149337, Final residual = 0.0013679, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0.0163648, Final residual = 0.00140099, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.0184817, Final residual = 0.00173408, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00954108, Final residual = 7.45286e-05, No Iterations 4
# time step continuity errors : sum local = 2.76977e-09, global = -4.04776e-10, cumulative = 7.52887e-09
# ExecutionTime = 6.72 s  ClockTime = 7 s
#
# Time = 2e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0135097, Final residual = 0.00126342, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0.0149788, Final residual = 0.00128547, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.0170098, Final residual = 0.00160318, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00842721, Final residual = 5.55198e-05, No Iterations 4
# time step continuity errors : sum local = 2.0779e-09, global = -2.91501e-10, cumulative = 7.23736e-09
# ExecutionTime = 7.03 s  ClockTime = 7 s
#
# Time = 2.1e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0122976, Final residual = 0.00116807, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0.0137637, Final residual = 0.00118931, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.0156566, Final residual = 0.00149021, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00748773, Final residual = 7.23816e-05, No Iterations 3
# time step continuity errors : sum local = 2.72486e-09, global = 1.07089e-09, cumulative = 8.30825e-09
# ExecutionTime = 7.34 s  ClockTime = 7 s
#
# Time = 2.2e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0112517, Final residual = 0.00108398, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0.0127222, Final residual = 0.00110538, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.0144969, Final residual = 0.00139351, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00671648, Final residual = 5.36975e-05, No Iterations 4
# time step continuity errors : sum local = 2.03147e-09, global = -2.78174e-10, cumulative = 8.03008e-09
# ExecutionTime = 7.66 s  ClockTime = 8 s
#
# Time = 2.3e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0103071, Final residual = 0.0010088, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0.0117549, Final residual = 0.00102284, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.0134874, Final residual = 0.00130127, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00601954, Final residual = 4.20942e-05, No Iterations 4
# time step continuity errors : sum local = 1.59956e-09, global = -2.10556e-10, cumulative = 7.81952e-09
# ExecutionTime = 7.97 s  ClockTime = 8 s
#
# Time = 2.4e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00948932, Final residual = 0.00094059, No Iterations 9
# smoothSolver:  Solving for Uy, Initial residual = 0.010882, Final residual = 0.000952763, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.01252, Final residual = 0.0012185, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00540694, Final residual = 3.6542e-05, No Iterations 4
# time step continuity errors : sum local = 1.39375e-09, global = -1.79021e-10, cumulative = 7.6405e-09
# ExecutionTime = 8.29 s  ClockTime = 8 s
#
# Time = 2.5e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00876595, Final residual = 0.000707383, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.0101125, Final residual = 0.000889037, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.0116671, Final residual = 0.00114378, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00487395, Final residual = 3.24871e-05, No Iterations 4
# time step continuity errors : sum local = 1.2431e-09, global = -1.62602e-10, cumulative = 7.4779e-09
# ExecutionTime = 8.64 s  ClockTime = 9 s
#
# Time = 2.6e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00808027, Final residual = 0.000656826, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00949656, Final residual = 0.000838517, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.0109872, Final residual = 0.00108425, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00437978, Final residual = 2.99647e-05, No Iterations 4
# time step continuity errors : sum local = 1.14981e-09, global = -1.49643e-10, cumulative = 7.32826e-09
# ExecutionTime = 8.97 s  ClockTime = 9 s
#
# Time = 2.7e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00748661, Final residual = 0.000614092, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00887116, Final residual = 0.00078616, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.0103248, Final residual = 0.00102578, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.0039434, Final residual = 2.90291e-05, No Iterations 4
# time step continuity errors : sum local = 1.11667e-09, global = -1.42283e-10, cumulative = 7.18598e-09
# ExecutionTime = 9.28 s  ClockTime = 9 s
#
# Time = 2.8e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00696373, Final residual = 0.000576232, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00829041, Final residual = 0.000736867, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00969266, Final residual = 0.000968547, No Iterations 10
# GAMG:  Solving for p, Initial residual = 0.00355393, Final residual = 2.83596e-05, No Iterations 4
# time step continuity errors : sum local = 1.0933e-09, global = -1.3933e-10, cumulative = 7.04665e-09
# ExecutionTime = 9.6 s  ClockTime = 10 s
#
# Time = 2.9e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00649605, Final residual = 0.00054194, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00776147, Final residual = 0.000691596, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00910139, Final residual = 0.000738844, No Iterations 11
# GAMG:  Solving for p, Initial residual = 0.00320946, Final residual = 2.96234e-05, No Iterations 4
# time step continuity errors : sum local = 1.14424e-09, global = -1.52922e-10, cumulative = 6.89372e-09
# ExecutionTime = 9.92 s  ClockTime = 10 s
#
# Time = 3e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00608078, Final residual = 0.000511351, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00728921, Final residual = 0.000651256, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00847676, Final residual = 0.000690146, No Iterations 11
# GAMG:  Solving for p, Initial residual = 0.00289193, Final residual = 2.76752e-05, No Iterations 4
# time step continuity errors : sum local = 1.07083e-09, global = -1.44646e-10, cumulative = 6.74908e-09
# ExecutionTime = 10.24 s  ClockTime = 10 s
#
# Time = 3.1e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0057008, Final residual = 0.000482749, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00685276, Final residual = 0.000613588, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00793493, Final residual = 0.000647914, No Iterations 11
# GAMG:  Solving for p, Initial residual = 0.00260689, Final residual = 2.45281e-05, No Iterations 4
# time step continuity errors : sum local = 9.50516e-10, global = -1.27419e-10, cumulative = 6.62166e-09
# ExecutionTime = 10.56 s  ClockTime = 11 s
#
# Time = 3.2e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0053522, Final residual = 0.000456102, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00644807, Final residual = 0.000578499, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.0074666, Final residual = 0.000611901, No Iterations 11
# GAMG:  Solving for p, Initial residual = 0.00235172, Final residual = 2.18195e-05, No Iterations 4
# time step continuity errors : sum local = 8.46704e-10, global = -1.12845e-10, cumulative = 6.50881e-09
# ExecutionTime = 10.89 s  ClockTime = 11 s
#
# Time = 3.3e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00503274, Final residual = 0.000431374, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00607394, Final residual = 0.000545961, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00705131, Final residual = 0.000580177, No Iterations 11
# GAMG:  Solving for p, Initial residual = 0.00212328, Final residual = 1.99701e-05, No Iterations 4
# time step continuity errors : sum local = 7.75887e-10, global = -1.03475e-10, cumulative = 6.40534e-09
# ExecutionTime = 11.2 s  ClockTime = 11 s
#
# Time = 3.4e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00474009, Final residual = 0.000408448, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00572896, Final residual = 0.000515841, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00667319, Final residual = 0.000551207, No Iterations 11
# GAMG:  Solving for p, Initial residual = 0.00191858, Final residual = 1.8771e-05, No Iterations 4
# time step continuity errors : sum local = 7.30099e-10, global = -9.79094e-11, cumulative = 6.30743e-09
# ExecutionTime = 11.53 s  ClockTime = 11 s
#
# Time = 3.5e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0044716, Final residual = 0.000387173, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00541068, Final residual = 0.000487946, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00632256, Final residual = 0.000524141, No Iterations 11
# GAMG:  Solving for p, Initial residual = 0.00173487, Final residual = 1.21931e-05, No Iterations 5
# time step continuity errors : sum local = 4.74723e-10, global = 8.03034e-11, cumulative = 6.38773e-09
# ExecutionTime = 11.86 s  ClockTime = 12 s
#
# Time = 3.6e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00422733, Final residual = 0.000367455, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00511861, Final residual = 0.000462027, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00599373, Final residual = 0.000497865, No Iterations 11
# GAMG:  Solving for p, Initial residual = 0.00156796, Final residual = 1.46185e-05, No Iterations 4
# time step continuity errors : sum local = 5.69672e-10, global = -7.44195e-11, cumulative = 6.31331e-09
# ExecutionTime = 12.19 s  ClockTime = 12 s
#
# Time = 3.7e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00399624, Final residual = 0.000348985, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00484325, Final residual = 0.000438103, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.0056842, Final residual = 0.000474606, No Iterations 11
# GAMG:  Solving for p, Initial residual = 0.00142215, Final residual = 1.05716e-05, No Iterations 5
# time step continuity errors : sum local = 4.12307e-10, global = 6.50936e-11, cumulative = 6.37841e-09
# ExecutionTime = 12.52 s  ClockTime = 12 s
#
# Time = 3.8e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00378807, Final residual = 0.000331818, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00459302, Final residual = 0.00041572, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00540476, Final residual = 0.000451813, No Iterations 11
# GAMG:  Solving for p, Initial residual = 0.00128721, Final residual = 9.15722e-06, No Iterations 5
# time step continuity errors : sum local = 3.57416e-10, global = 5.73258e-11, cumulative = 6.43573e-09
# ExecutionTime = 12.86 s  ClockTime = 13 s
#
# Time = 3.9e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00359222, Final residual = 0.000315738, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00435606, Final residual = 0.000394932, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00513453, Final residual = 0.0004307, No Iterations 11
# GAMG:  Solving for p, Initial residual = 0.00116787, Final residual = 8.50783e-06, No Iterations 5
# time step continuity errors : sum local = 3.32306e-10, global = 5.14411e-11, cumulative = 6.48717e-09
# ExecutionTime = 13.19 s  ClockTime = 13 s
#
# Time = 4e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.003411, Final residual = 0.000300683, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00413704, Final residual = 0.000375535, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00488712, Final residual = 0.000411074, No Iterations 11
# GAMG:  Solving for p, Initial residual = 0.00106085, Final residual = 8.15009e-06, No Iterations 5
# time step continuity errors : sum local = 3.18543e-10, global = 4.73657e-11, cumulative = 6.53454e-09
# ExecutionTime = 13.53 s  ClockTime = 13 s
#
# Time = 4.1e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0032429, Final residual = 0.000286566, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00393311, Final residual = 0.000357413, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00465627, Final residual = 0.000392594, No Iterations 11
# GAMG:  Solving for p, Initial residual = 0.000964502, Final residual = 7.82355e-06, No Iterations 5
# time step continuity errors : sum local = 3.05965e-10, global = 4.36891e-11, cumulative = 6.57823e-09
# ExecutionTime = 13.92 s  ClockTime = 14 s
#
# Time = 4.2e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00308642, Final residual = 0.000273313, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00374255, Final residual = 0.000340438, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00443899, Final residual = 0.00037513, No Iterations 11
# GAMG:  Solving for p, Initial residual = 0.000877641, Final residual = 7.46316e-06, No Iterations 5
# time step continuity errors : sum local = 2.92034e-10, global = 4.00676e-11, cumulative = 6.6183e-09
# ExecutionTime = 14.3 s  ClockTime = 14 s
#
# Time = 4.3e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00294045, Final residual = 0.000260853, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00356403, Final residual = 0.000324506, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00423465, Final residual = 0.000358649, No Iterations 11
# GAMG:  Solving for p, Initial residual = 0.00079933, Final residual = 7.08459e-06, No Iterations 5
# time step continuity errors : sum local = 2.77364e-10, global = 3.66062e-11, cumulative = 6.6549e-09
# ExecutionTime = 14.64 s  ClockTime = 15 s
#
# Time = 4.4e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00280397, Final residual = 0.000249122, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.0033968, Final residual = 0.000309551, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.0040427, Final residual = 0.000343103, No Iterations 11
# GAMG:  Solving for p, Initial residual = 0.000728733, Final residual = 6.71314e-06, No Iterations 5
# time step continuity errors : sum local = 2.62948e-10, global = 3.34223e-11, cumulative = 6.68833e-09
# ExecutionTime = 14.98 s  ClockTime = 15 s
#
# Time = 4.5e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00267615, Final residual = 0.000238063, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00323994, Final residual = 0.000295499, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00386227, Final residual = 0.000328424, No Iterations 11
# GAMG:  Solving for p, Initial residual = 0.000665112, Final residual = 6.3628e-06, No Iterations 5
# time step continuity errors : sum local = 2.49337e-10, global = 3.05606e-11, cumulative = 6.71889e-09
# ExecutionTime = 15.31 s  ClockTime = 15 s
#
# Time = 4.6e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00255624, Final residual = 0.000227626, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00309265, Final residual = 0.000282279, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00369233, Final residual = 0.000314544, No Iterations 11
# GAMG:  Solving for p, Initial residual = 0.000607709, Final residual = 6.03648e-06, No Iterations 5
# time step continuity errors : sum local = 2.36648e-10, global = 2.8008e-11, cumulative = 6.74689e-09
# ExecutionTime = 15.7 s  ClockTime = 16 s
#
# Time = 4.7e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00244355, Final residual = 0.000217767, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00295404, Final residual = 0.00026982, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00353187, Final residual = 0.000301403, No Iterations 11
# GAMG:  Solving for p, Initial residual = 0.000556066, Final residual = 4.174e-06, No Iterations 6
# time step continuity errors : sum local = 1.63697e-10, global = -2.00926e-11, cumulative = 6.7268e-09
# ExecutionTime = 16.1 s  ClockTime = 16 s
#
# Time = 4.8e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00233755, Final residual = 0.000208396, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00282411, Final residual = 0.000258042, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.0033795, Final residual = 0.000288641, No Iterations 11
# GAMG:  Solving for p, Initial residual = 0.000509704, Final residual = 4.70861e-06, No Iterations 5
# time step continuity errors : sum local = 1.84732e-10, global = 2.00591e-11, cumulative = 6.74686e-09
# ExecutionTime = 16.49 s  ClockTime = 16 s
#
# Time = 4.9e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00223734, Final residual = 0.000199656, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00269996, Final residual = 0.000246987, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00323589, Final residual = 0.000277185, No Iterations 11
# GAMG:  Solving for p, Initial residual = 0.000468163, Final residual = 3.70295e-06, No Iterations 6
# time step continuity errors : sum local = 1.45327e-10, global = -1.65313e-11, cumulative = 6.73033e-09
# ExecutionTime = 16.89 s  ClockTime = 17 s
#
# Time = 5e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.0021433, Final residual = 0.000191226, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00258511, Final residual = 0.000236507, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00310217, Final residual = 0.000265794, No Iterations 11
# GAMG:  Solving for p, Initial residual = 0.000430228, Final residual = 3.18683e-06, No Iterations 6
# time step continuity errors : sum local = 1.25113e-10, global = -1.38803e-11, cumulative = 6.71645e-09
# ExecutionTime = 17.3 s  ClockTime = 17 s
#
# Time = 5.1e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00205383, Final residual = 0.000183334, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.002475, Final residual = 0.000226615, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00297246, Final residual = 0.000255143, No Iterations 11
# GAMG:  Solving for p, Initial residual = 0.000395833, Final residual = 3.01431e-06, No Iterations 6
# time step continuity errors : sum local = 1.18376e-10, global = -1.26136e-11, cumulative = 6.70384e-09
# ExecutionTime = 17.66 s  ClockTime = 18 s
#
# Time = 5.2e-05
#
# smoothSolver:  Solving for Ux, Initial residual = 0.00196952, Final residual = 0.000175823, No Iterations 10
# smoothSolver:  Solving for Uy, Initial residual = 0.00237146, Final residual = 0.000217262, No Iterations 10
# smoothSolver:  Solving for Uz, Initial residual = 0.00285129, Final residual = 0.000245069, No Iterations 11
# GAMG:  Solving for p, Initial residual = 0.000364871, Final residual = 2.91529e-06, No Iterations 6
# time step continuity errors : sum local = 1.14521e-10, global = -1.16946e-11, cumulative = 6.69214e-09
# ...
# ExecutionTime = 150.69 s  ClockTime = 151 s
#
# Time = 0.000487
#
# smoothSolver:  Solving for Ux, Initial residual = 2.29668e-08, Final residual = 8.60799e-09, No Iterations 4
# smoothSolver:  Solving for Uy, Initial residual = 1.6815e-08, Final residual = 8.18259e-09, No Iterations 3
# smoothSolver:  Solving for Uz, Initial residual = 1.41956e-08, Final residual = 8.79635e-09, No Iterations 2
# GAMG:  Solving for p, Initial residual = 9.35136e-08, Final residual = 9.35136e-08, No Iterations 0
# time step continuity errors : sum local = 3.70037e-12, global = 1.26815e-14, cumulative = 6.74806e-09
# ExecutionTime = 150.9 s  ClockTime = 151 s
#
# Time = 0.000488
#
# smoothSolver:  Solving for Ux, Initial residual = 2.09949e-08, Final residual = 9.95047e-09, No Iterations 3
# smoothSolver:  Solving for Uy, Initial residual = 1.57609e-08, Final residual = 9.6907e-09, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 1.37262e-08, Final residual = 8.54824e-09, No Iterations 2
# GAMG:  Solving for p, Initial residual = 1.06433e-07, Final residual = 1.29957e-08, No Iterations 1
# time step continuity errors : sum local = 5.14243e-13, global = 1.33122e-14, cumulative = 6.74808e-09
# ExecutionTime = 151.12 s  ClockTime = 151 s
#
# Time = 0.000489
#
# smoothSolver:  Solving for Ux, Initial residual = 4.44857e-08, Final residual = 9.79518e-09, No Iterations 5
# smoothSolver:  Solving for Uy, Initial residual = 3.1863e-08, Final residual = 9.99228e-09, No Iterations 3
# smoothSolver:  Solving for Uz, Initial residual = 2.65745e-08, Final residual = 7.78331e-09, No Iterations 3
# GAMG:  Solving for p, Initial residual = 3.44884e-08, Final residual = 3.44884e-08, No Iterations 0
# time step continuity errors : sum local = 1.36472e-12, global = 1.20426e-14, cumulative = 6.74809e-09
# ExecutionTime = 151.33 s  ClockTime = 151 s
#
# Time = 0.00049
#
# smoothSolver:  Solving for Ux, Initial residual = 2.96415e-08, Final residual = 8.69448e-09, No Iterations 5
# smoothSolver:  Solving for Uy, Initial residual = 2.0629e-08, Final residual = 9.09471e-09, No Iterations 3
# smoothSolver:  Solving for Uz, Initial residual = 1.71311e-08, Final residual = 9.1834e-09, No Iterations 2
# GAMG:  Solving for p, Initial residual = 6.03035e-08, Final residual = 6.03035e-08, No Iterations 0
# time step continuity errors : sum local = 2.38623e-12, global = 1.11177e-14, cumulative = 6.7481e-09
# ExecutionTime = 151.55 s  ClockTime = 151 s
#
# Time = 0.000491
#
# smoothSolver:  Solving for Ux, Initial residual = 2.62194e-08, Final residual = 9.81318e-09, No Iterations 4
# smoothSolver:  Solving for Uy, Initial residual = 1.75052e-08, Final residual = 8.41996e-09, No Iterations 3
# smoothSolver:  Solving for Uz, Initial residual = 1.44435e-08, Final residual = 8.81202e-09, No Iterations 2
# GAMG:  Solving for p, Initial residual = 8.08837e-08, Final residual = 8.08837e-08, No Iterations 0
# time step continuity errors : sum local = 3.2006e-12, global = 1.03939e-14, cumulative = 6.74811e-09
# ExecutionTime = 151.75 s  ClockTime = 152 s
#
# Time = 0.000492
#
# smoothSolver:  Solving for Ux, Initial residual = 2.37648e-08, Final residual = 8.91946e-09, No Iterations 4
# smoothSolver:  Solving for Uy, Initial residual = 1.61454e-08, Final residual = 9.88865e-09, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 1.37821e-08, Final residual = 8.53278e-09, No Iterations 2
# GAMG:  Solving for p, Initial residual = 9.90412e-08, Final residual = 9.90412e-08, No Iterations 0
# time step continuity errors : sum local = 3.9191e-12, global = 9.64757e-15, cumulative = 6.74812e-09
# ExecutionTime = 151.96 s  ClockTime = 152 s
#
# Time = 0.000493
#
# smoothSolver:  Solving for Ux, Initial residual = 2.16724e-08, Final residual = 8.1379e-09, No Iterations 4
# smoothSolver:  Solving for Uy, Initial residual = 1.52336e-08, Final residual = 9.37842e-09, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 1.33114e-08, Final residual = 8.28266e-09, No Iterations 2
# GAMG:  Solving for p, Initial residual = 1.15122e-07, Final residual = 1.4051e-08, No Iterations 1
# time step continuity errors : sum local = 5.56004e-13, global = 1.09859e-14, cumulative = 6.74813e-09
# ExecutionTime = 152.18 s  ClockTime = 152 s
#
# Time = 0.000494
#
# smoothSolver:  Solving for Ux, Initial residual = 4.87698e-08, Final residual = 8.53619e-09, No Iterations 6
# smoothSolver:  Solving for Uy, Initial residual = 3.36949e-08, Final residual = 8.30453e-09, No Iterations 4
# smoothSolver:  Solving for Uz, Initial residual = 2.72182e-08, Final residual = 9.77184e-09, No Iterations 2
# GAMG:  Solving for p, Initial residual = 4.03523e-08, Final residual = 4.03523e-08, No Iterations 0
# time step continuity errors : sum local = 1.59676e-12, global = 1.07488e-14, cumulative = 6.74814e-09
# ExecutionTime = 152.4 s  ClockTime = 152 s
#
# Time = 0.000495
#
# smoothSolver:  Solving for Ux, Initial residual = 3.20576e-08, Final residual = 9.44304e-09, No Iterations 5
# smoothSolver:  Solving for Uy, Initial residual = 2.14872e-08, Final residual = 9.41396e-09, No Iterations 3
# smoothSolver:  Solving for Uz, Initial residual = 1.70732e-08, Final residual = 8.90105e-09, No Iterations 2
# GAMG:  Solving for p, Initial residual = 6.89186e-08, Final residual = 6.89186e-08, No Iterations 0
# time step continuity errors : sum local = 2.72714e-12, global = 1.08511e-14, cumulative = 6.74815e-09
# ExecutionTime = 152.61 s  ClockTime = 153 s
#
# Time = 0.000496
#
# smoothSolver:  Solving for Ux, Initial residual = 2.82908e-08, Final residual = 8.42771e-09, No Iterations 5
# smoothSolver:  Solving for Uy, Initial residual = 1.81035e-08, Final residual = 8.69233e-09, No Iterations 3
# smoothSolver:  Solving for Uz, Initial residual = 1.3951e-08, Final residual = 8.45325e-09, No Iterations 2
# GAMG:  Solving for p, Initial residual = 9.40772e-08, Final residual = 9.40772e-08, No Iterations 0
# time step continuity errors : sum local = 3.72267e-12, global = 1.09347e-14, cumulative = 6.74816e-09
# ExecutionTime = 152.83 s  ClockTime = 153 s
#
# Time = 0.000497
#
# smoothSolver:  Solving for Ux, Initial residual = 2.52908e-08, Final residual = 9.52927e-09, No Iterations 4
# smoothSolver:  Solving for Uy, Initial residual = 1.66312e-08, Final residual = 8.07422e-09, No Iterations 3
# smoothSolver:  Solving for Uz, Initial residual = 1.31814e-08, Final residual = 8.11891e-09, No Iterations 2
# GAMG:  Solving for p, Initial residual = 1.13904e-07, Final residual = 1.37921e-08, No Iterations 1
# time step continuity errors : sum local = 5.45757e-13, global = 1.09453e-14, cumulative = 6.74817e-09
# ExecutionTime = 153.04 s  ClockTime = 153 s
#
# Time = 0.000498
#
# smoothSolver:  Solving for Ux, Initial residual = 4.4278e-08, Final residual = 9.38771e-09, No Iterations 5
# smoothSolver:  Solving for Uy, Initial residual = 3.08635e-08, Final residual = 9.28055e-09, No Iterations 3
# smoothSolver:  Solving for Uz, Initial residual = 2.54975e-08, Final residual = 9.10416e-09, No Iterations 2
# GAMG:  Solving for p, Initial residual = 3.35736e-08, Final residual = 3.35736e-08, No Iterations 0
# time step continuity errors : sum local = 1.32852e-12, global = 9.75735e-15, cumulative = 6.74818e-09
# ExecutionTime = 153.26 s  ClockTime = 153 s
#
# Time = 0.000499
#
# smoothSolver:  Solving for Ux, Initial residual = 2.83305e-08, Final residual = 8.30972e-09, No Iterations 5
# smoothSolver:  Solving for Uy, Initial residual = 1.93787e-08, Final residual = 8.39883e-09, No Iterations 3
# smoothSolver:  Solving for Uz, Initial residual = 1.59967e-08, Final residual = 8.29114e-09, No Iterations 2
# GAMG:  Solving for p, Initial residual = 5.86303e-08, Final residual = 5.86303e-08, No Iterations 0
# time step continuity errors : sum local = 2.32002e-12, global = 8.88723e-15, cumulative = 6.74819e-09
# ExecutionTime = 153.46 s  ClockTime = 153 s
#
# Time = 0.0005
#
# smoothSolver:  Solving for Ux, Initial residual = 2.49196e-08, Final residual = 9.35318e-09, No Iterations 4
# smoothSolver:  Solving for Uy, Initial residual = 1.61407e-08, Final residual = 9.76834e-09, No Iterations 2
# smoothSolver:  Solving for Uz, Initial residual = 1.30368e-08, Final residual = 9.99348e-09, No Iterations 1
# GAMG:  Solving for p, Initial residual = 7.86168e-08, Final residual = 7.86168e-08, No Iterations 0
# time step continuity errors : sum local = 3.11089e-12, global = 8.19146e-15, cumulative = 6.7482e-09
# ExecutionTime = 154.02 s  ClockTime = 154 s
#
# End
#
#
# >>> postProcess -func 'flowRatePatch(name=inlet)'
#
# /*---------------------------------------------------------------------------*\
# | =========                 |                                                 |
# | \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox           |
# |  \\    /   O peration     | Version:  2412                                  |
# |   \\  /    A nd           | Website:  www.openfoam.com                      |
# |    \\/     M anipulation  |                                                 |
# \*---------------------------------------------------------------------------*/
# Build  : _f00230df-20250528 OPENFOAM=2412 patch=250528 version=2412
# Arch   : "LSB;label=32;scalar=64"
# Exec   : postProcess -func flowRatePatch(name=inlet)
# Date   : Aug 08 2025
# Time   : 13:41:20
# Host   : e-10aux32876g5
# PID    : 2182317
# I/O    : uncollated
# Case   : /home/h09435ap/porePermFoam
# nProcs : 1
# trapFpe: Floating point exception trapping enabled (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 5, maxFileModificationPolls 20)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# --> FOAM Warning :
#     From static Foam::IOstreamOption::compressionType Foam::IOstreamOption::compressionEnum(const Foam::word&, Foam::IOstreamOption::compressionType)
#     in file db/options/IOstreamOption.C at line 189
#     Unknown compression specifier 'uncompressed' using compression off
# Create mesh for time = 0
#
# surfaceFieldValue flowRatePatch(name=inlet):
#     operation     = sum
#
#
# Time = 0
# --> FOAM Warning :
#     From virtual bool Foam::functionObjects::fieldSelection::checkSelection()
#     in file functionObjects/fieldSelections/fieldSelection/fieldSelection.C at line 179
#     Field phi not found
#
# Reading fields:
#
# Executing functionObjects
# surfaceFieldValue flowRatePatch(name=inlet) write:
#     total faces   = 1875
#     total area    = 1.65778e-08
#
# --> FOAM Warning :
#     From Foam::label Foam::functionObjects::fieldValues::surfaceFieldValue::writeAll(const vectorField&, const Foam::Field<Type>&, const pointField&, const faceList&) [with WeightType = double; Foam::label = int; Foam::vectorField = Foam::Field<Foam::Vector<double> >; Foam::pointField = Foam::Field<Foam::Vector<double> >; Foam::faceList = Foam::List<Foam::face>]
#     in file fieldValues/surfaceFieldValue/surfaceFieldValueTemplates.C at line 384
#     Requested field phi not found in database and not processed
#
#
# Time = 0.0001
#
# Reading fields:
#     surfaceScalarField: phi
#
# Executing functionObjects
# surfaceFieldValue flowRatePatch(name=inlet) write:
#     sum(inlet) of phi = -4.00589e-12
#
#
# Time = 0.0002
#
# Reading fields:
#     surfaceScalarField: phi
#
# Executing functionObjects
# surfaceFieldValue flowRatePatch(name=inlet) write:
#     sum(inlet) of phi = -4.12136e-12
#
#
# Time = 0.0003
#
# Reading fields:
#     surfaceScalarField: phi
#
# Executing functionObjects
# surfaceFieldValue flowRatePatch(name=inlet) write:
#     sum(inlet) of phi = -4.12712e-12
#
#
# Time = 0.0004
#
# Reading fields:
#     surfaceScalarField: phi
#
# Executing functionObjects
# surfaceFieldValue flowRatePatch(name=inlet) write:
#     sum(inlet) of phi = -4.12742e-12
#
#
# Time = 0.0005
#
# Reading fields:
#     surfaceScalarField: phi
#
# Executing functionObjects
# surfaceFieldValue flowRatePatch(name=inlet) write:
#     sum(inlet) of phi = -4.12744e-12
#
#
# End
#
#
# >>> postProcess -func 'flowRatePatch(name=outlet)'
#
# /*---------------------------------------------------------------------------*\
# | =========                 |                                                 |
# | \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox           |
# |  \\    /   O peration     | Version:  2412                                  |
# |   \\  /    A nd           | Website:  www.openfoam.com                      |
# |    \\/     M anipulation  |                                                 |
# \*---------------------------------------------------------------------------*/
# Build  : _f00230df-20250528 OPENFOAM=2412 patch=250528 version=2412
# Arch   : "LSB;label=32;scalar=64"
# Exec   : postProcess -func flowRatePatch(name=outlet)
# Date   : Aug 08 2025
# Time   : 13:41:21
# Host   : e-10aux32876g5
# PID    : 2182322
# I/O    : uncollated
# Case   : /home/h09435ap/porePermFoam
# nProcs : 1
# trapFpe: Floating point exception trapping enabled (FOAM_SIGFPE).
# fileModificationChecking : Monitoring run-time modified files using timeStampMaster (fileModificationSkew 5, maxFileModificationPolls 20)
# allowSystemOperations : Allowing user-supplied system call operations
#
# // * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * //
# Create time
#
# --> FOAM Warning :
#     From static Foam::IOstreamOption::compressionType Foam::IOstreamOption::compressionEnum(const Foam::word&, Foam::IOstreamOption::compressionType)
#     in file db/options/IOstreamOption.C at line 189
#     Unknown compression specifier 'uncompressed' using compression off
# Create mesh for time = 0
#
# surfaceFieldValue flowRatePatch(name=outlet):
#     operation     = sum
#
#
# Time = 0
# --> FOAM Warning :
#     From virtual bool Foam::functionObjects::fieldSelection::checkSelection()
#     in file functionObjects/fieldSelections/fieldSelection/fieldSelection.C at line 179
#     Field phi not found
#
# Reading fields:
#
# Executing functionObjects
# surfaceFieldValue flowRatePatch(name=outlet) write:
#     total faces   = 1544
#     total area    = 1.36513e-08
#
# --> FOAM Warning :
#     From Foam::label Foam::functionObjects::fieldValues::surfaceFieldValue::writeAll(const vectorField&, const Foam::Field<Type>&, const pointField&, const faceList&) [with WeightType = double; Foam::label = int; Foam::vectorField = Foam::Field<Foam::Vector<double> >; Foam::pointField = Foam::Field<Foam::Vector<double> >; Foam::faceList = Foam::List<Foam::face>]
#     in file fieldValues/surfaceFieldValue/surfaceFieldValueTemplates.C at line 384
#     Requested field phi not found in database and not processed
#
#
# Time = 0.0001
#
# Reading fields:
#     surfaceScalarField: phi
#
# Executing functionObjects
# surfaceFieldValue flowRatePatch(name=outlet) write:
#     sum(outlet) of phi = 4.00589e-12
#
#
# Time = 0.0002
#
# Reading fields:
#     surfaceScalarField: phi
#
# Executing functionObjects
# surfaceFieldValue flowRatePatch(name=outlet) write:
#     sum(outlet) of phi = 4.12137e-12
#
#
# Time = 0.0003
#
# Reading fields:
#     surfaceScalarField: phi
#
# Executing functionObjects
# surfaceFieldValue flowRatePatch(name=outlet) write:
#     sum(outlet) of phi = 4.12712e-12
#
#
# Time = 0.0004
#
# Reading fields:
#     surfaceScalarField: phi
#
# Executing functionObjects
# surfaceFieldValue flowRatePatch(name=outlet) write:
#     sum(outlet) of phi = 4.12742e-12
#
#
# Time = 0.0005
#
# Reading fields:
#     surfaceScalarField: phi
#
# Executing functionObjects
# surfaceFieldValue flowRatePatch(name=outlet) write:
#     sum(outlet) of phi = 4.12744e-12
#
#
# End
#
# Warning: 6 times vs 5 rates for 'inlet'
# Warning: 6 times vs 5 rates for 'outlet'
# Wrote 5 records with area=1.65778e-08 to q_in.csv
# Wrote 5 records with area=1.36513e-08 to q_out.csv
#
# --- inlet fluxes ---
# t=0         , q_in=-4.00589e-12, A_in=1.65778e-08
# t=0.0001    , q_in=-4.12136e-12, A_in=1.65778e-08
# t=0.0002    , q_in=-4.12712e-12, A_in=1.65778e-08
# t=0.0003    , q_in=-4.12742e-12, A_in=1.65778e-08
# t=0.0004    , q_in=-4.12744e-12, A_in=1.65778e-08
#
# --- outlet fluxes ---
# t=0         , q_out=4.00589e-12, A_out=1.36513e-08
# t=0.0001    , q_out=4.12137e-12, A_out=1.36513e-08
# t=0.0002    , q_out=4.12712e-12, A_out=1.36513e-08
# t=0.0003    , q_out=4.12742e-12, A_out=1.36513e-08
# t=0.0004    , q_out=4.12744e-12, A_out=1.36513e-08

# %% [markdown]
# ## 6️⃣ Load Simulation Results
#
# The solver outputs a `q_in.csv` file containing:
# - Cross-sectional area.
# - Volumetric flow rate.
#
# We read it with `pandas` for further calculations.

# %%
df_q_area = pd.read_csv("q_in.csv")
df_q_area.head()
# Out:
#      time  flowRate_phi          area
# 0  0.0000 -4.005890e-12  1.657780e-08
# 1  0.0001 -4.121360e-12  1.657780e-08
# 2  0.0002 -4.127120e-12  1.657780e-08
# 3  0.0003 -4.127420e-12  1.657780e-08
# 4  0.0004 -4.127440e-12  1.657780e-08

# %% [markdown]
# ## 7️⃣ Compute Porosity and Permeability
#
# **Porosity** is computed directly from the voxel geometry.
# **Permeability** is computed from Darcy’s law:
#
#
# $$k = \frac{Q \, \mu \, L}{A \, \Delta P}$$
#
#
# Where:
# - $Q$ = volumetric flow rate
# - $\mu$ = fluid viscosity (Pa·s)
# - $L$ = sample length (m)
# - $A$ = cross-sectional area (m²)
# - $\Delta P$ = pressure difference (Pa)

# %%
phi = sft.vti_phi(vti_path)
print(f"Porosity: {phi:.02%}")

# Cross-sectional area
A = shape[1] * shape[2] * scale**2
miu = 1e-3  # fluid viscosity [Pa·s]
L = shape[0] * scale  # length [m]

# Flow rate from last timestep
Q = np.abs(df_q_area["flowRate_phi"].iloc[-1])

# Darcy's law
k = Q * miu * L / (A * dp)

print(f"Permeability: {k:.02e} m^2")
print(f"Permeability: {k * 1.01324997e15:.02f} md")
# Out:
# Porosity: 24.81%
# Permeability: 1.37e-11 m^2
# Permeability: 13924.18 md
